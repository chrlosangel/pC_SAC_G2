# %%
# -*- coding: utf-8 -*-
"""
Carlos Angel

Examples to run main functions of the package.
v0.1 : 2023/09/15
v1.0 : 2023/11/05
v2.0 : 2023/12/12 (Added celltype and new reconstruct functions)
v3.0 : 2024/01/02 (Added synthetic data module)
Python version: 3.10.12
"""


import importlib
import numpy as np
import scipy as scp
import torch
import pandas as pd
import hicstraw
from pathlib import Path
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import pyplot as plt
from matplotlib import gridspec
import matplotlib.pyplot as plt 
import seaborn as sns
import sys
from math import trunc
import os

sys.path.append('/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning')

from src import utils
from src import globals
from src import submatrices
from src import reconstruct
np.set_printoptions(threshold=sys.maxsize)
# Out:
# Importing pcSAC libraries...

# %% [markdown]
# Whole and non-split chains options:
# The point here is that we wanted to split the amount of chains to start reconstructing one forward and one reverse.

# %%
#file and bool_res are default
#lrbin refers to the number of bins in one HR bin, so if HR is 5kb and LR is 20kb, lrbin=4
utils.run_genData(
    chr=globals.chromosome,
    start=globals.start,
    end=globals.end,
    downsample_factor=16,
    hic_res=5000, 
    lrbin=4,
    split_chains=False
)
# Out:
# Submitted batch job 38461777

# %%
utils.run_genData(
    chr=globals.chromosome,
    start=globals.start,
    end=globals.end,
    downsample_factor=1,
    hic_res=5000, 
    lrbin=4,
    split_chains=False
)
# Out:
# Submitted batch job 38616254

# %%
#Split chains is only available for whole matrices, do not use for submatrices
utils.run_pcSAC(downsampling_factor=16,
                         lrf=20,
                         run_option="whole",
                         number_chains=10000,
                         split_chains=False,
                         region_size=globals.size,
                         hic_res=globals.hic_res)
# Out:
# Submitted batch job 38462685

# %%
#Split chains is only available for whole matrices, do not use for submatrices
utils.run_pcSAC(downsampling_factor=1,
                         lrf=20,
                         run_option="whole",
                         number_chains=1000,
                         split_chains=False,
                         region_size=globals.size,
                         hic_res=globals.hic_res)
# Out:
# Submitted batch job 38617236

# %%
#add comparison test
# it is also available on utils module, must be run with that module but sisnce we just implemented it we dont want to reload the kernel
reconstruct.run_reconstruction(downsampling_factor=16,
                                lrf=20,
                                run_option="whole",
                                number_chains=10000,
                                region_size = globals.size,
                                hic_res = globals.hic_res,
                                chromosome = globals.chromosome,
                                start=globals.start)

# %%
#splitting matrices is interfeiring because the amount of chains so we need to implement some changes
reconstruct.run_reconstruction(downsampling_factor=16,
                                lrf=20,
                                run_option="whole",
                                number_chains=10000,
                                region_size = globals.size,
                                hic_res = globals.hic_res,
                                chromosome = globals.chromosome,
                                start=globals.start)
# Out:
# Submitted batch job 38557231

# %%
#tmp for Gamze
reconstruct.run_reconstruction(downsampling_factor=16,
                                lrf=20,
                                run_option="whole",
                                number_chains=5000,
                                region_size = globals.size,
                                hic_res = globals.hic_res,
                                chromosome = globals.chromosome,
                                start=globals.start)
# Out:
# Submitted batch job 38513121

# %% [markdown]
# ### Split chains option

# %%
#Split chains is only available for whole matrices, do not use for submatrices
utils.run_genData(
    chr=globals.chromosome,
    start=globals.start,
    end=globals.end,
    downsample_factor=16,
    hic_res=5000, 
    lrbin=4,
    split_chains=True,
    file=globals.hic_file
)
# Out:
# Submitted batch job 41200767

# %%
#Split chains is only available for whole matrices, do not use for submatrices
utils.run_pcSAC(downsampling_factor=16,
                         lrf=20,
                         run_option="whole",
                         number_chains=10000,
                         split_chains=True,
                         region_size=globals.size,
                         hic_res=globals.hic_res)
# Out:
# Submitted batch job 38477635

# %% [markdown]
# ### Toy examples

# %%
utils.run_genData(
    chr=globals.chromosome,
    start=globals.start,
    end=globals.start + 600000,
    downsample_factor=16,
    hic_res=5000, 
    lrbin=4,
    split_chains=True
)
# Out:
# Submitted batch job 40206755

# %%
#Testing with all interactions in the specific range 
#Remember 1100 chains

utils.run_pcSAC(downsampling_factor=16,
                         lrf=20,
                         run_option="whole",
                         number_chains=1100,
                         split_chains=False,
                         region_size=globals.size,
                         hic_res=globals.hic_res)
# Out:
# Submitted batch job 40211847

# %% [markdown]
# ### New compiler version

# %% [markdown]
# ## 10kb resolution workflow

# %% [markdown]
# ### Tested regions  chr20

# %%
# Generate data for each region

my_regions = ['chr20:100000-2100000', 
              'chr20:20000000-21500000', 
              'chr20:42000000-43800000', 
              'chr20:2100000-3800000',
              'chr20:5000000-6950000',
              'chr20:43801000-45710000',
              'chr20:47622000-49500000',
              'chr20:45710000-47620000',
              ]

downsampling_factor = [16,25,50,100] 
n_chains = 10000
cell = 'GM12878'
hic_res = 10000

for region in my_regions:
    chrom, positions = region.split(':')
    chrom = chrom.replace('chr', '')
    start, end = map(int, positions.split('-'))
    print("Generating data for region:")
    print(f"Chromosome:{chrom}, {start}, {end}")
    for ds in downsampling_factor:
        print(f"Downsampling factor: {ds}")
        utils.run_genData(
        chr=globals.chromosome,
        start=start,
        end=end,
        downsample_factor=ds,
        hic_res=hic_res, 
        lrbin=2,
        split_chains=False,
        file=globals.hic_file
    )
    print("Input data generated\n")
# Out:
# Generating data for region:
# Chromosome:20, 100000, 2100000
# Downsampling factor: 16
# Submitted batch job 41699740
# Downsampling factor: 25
# Submitted batch job 41699741
# Downsampling factor: 50
# Submitted batch job 41699742
# Downsampling factor: 100
# Submitted batch job 41699743
# Input data generated
#
# Generating data for region:
# Chromosome:20, 20000000, 21500000
# Downsampling factor: 16
# Submitted batch job 41699744
# Downsampling factor: 25
# Submitted batch job 41699745
# Downsampling factor: 50
# Submitted batch job 41699746
# Downsampling factor: 100
# Submitted batch job 41699747
# Input data generated
#
# Generating data for region:
# Chromosome:20, 42000000, 43800000
# Downsampling factor: 16
# Submitted batch job 41699748
# Downsampling factor: 25
# Submitted batch job 41699749
# Downsampling factor: 50
# Submitted batch job 41699750
# Downsampling factor: 100
# Submitted batch job 41699751
# Input data generated
#
# Generating data for region:
# Chromosome:20, 2100000, 3800000
# Downsampling factor: 16
# Submitted batch job 41699752
# Downsampling factor: 25
# Submitted batch job 41699753
# Downsampling factor: 50
# Submitted batch job 41699754
# Downsampling factor: 100
# Submitted batch job 41699755
# Input data generated
#
# Generating data for region:
# Chromosome:20, 5000000, 6950000
# Downsampling factor: 16
# Submitted batch job 41699756
# Downsampling factor: 25
# Submitted batch job 41699757
# Downsampling factor: 50
# Submitted batch job 41699758
# Downsampling factor: 100
# Submitted batch job 41699759
# Input data generated
#
# Generating data for region:
# Chromosome:20, 43801000, 45710000
# Downsampling factor: 16
# Submitted batch job 41699760
# Downsampling factor: 25
# Submitted batch job 41699761
# Downsampling factor: 50
# Submitted batch job 41699762
# Downsampling factor: 100
# Submitted batch job 41699763
# Input data generated
#
# Generating data for region:
# Chromosome:20, 47622000, 49500000
# Downsampling factor: 16
# Submitted batch job 41699764
# Downsampling factor: 25
# Submitted batch job 41699765
# Downsampling factor: 50
# Submitted batch job 41699766
# Downsampling factor: 100
# Submitted batch job 41699767
# Input data generated
#
# Generating data for region:
# Chromosome:20, 45710000, 47620000
# Downsampling factor: 16
# Submitted batch job 41699768
# Downsampling factor: 25
# Submitted batch job 41699769
# Downsampling factor: 50
# Submitted batch job 41699770
# Downsampling factor: 100
# Submitted batch job 41699771
# Input data generated

# %%
#Generating ensambles for each region

#for 5k we only tested 16 and 25, if it works for tomorrow we can run the rest
for region in my_regions:
    chrom, positions = region.split(':')
    chrom = chrom.replace('chr', '')
    start, end = map(int, positions.split('-'))
    for ds in downsampling_factor:
        utils.run_pcSAC(
            downsampling_factor=ds,
            lrf=20,
            run_option="whole",
            number_chains=n_chains,
            split_chains=False,
            region_size=int(end-start),
            hic_res=hic_res,
            cell=cell)
        
        print("Running reconstruction for")
        print(f"Chromosome:{chrom}, {start}, {end}")
        print(f"Downsampling factor: {ds}\n")
# Out:
# Submitted batch job 41699887
# Running reconstruction for
# Chromosome:20, 100000, 2100000
# Downsampling factor: 16
#
# Submitted batch job 41699888
# Running reconstruction for
# Chromosome:20, 100000, 2100000
# Downsampling factor: 25
#
# Submitted batch job 41699889
# Running reconstruction for
# Chromosome:20, 20000000, 21500000
# Downsampling factor: 16
#
# Submitted batch job 41699890
# Running reconstruction for
# Chromosome:20, 20000000, 21500000
# Downsampling factor: 25
#
# Submitted batch job 41699891
# Running reconstruction for
# Chromosome:20, 42000000, 43800000
# Downsampling factor: 16
#
# Submitted batch job 41699892
# Running reconstruction for
# Chromosome:20, 42000000, 43800000
# Downsampling factor: 25
#
# Submitted batch job 41699893
# Running reconstruction for
# Chromosome:20, 2100000, 3800000
# Downsampling factor: 16
#
# Submitted batch job 41699894
# Running reconstruction for
# Chromosome:20, 2100000, 3800000
# Downsampling factor: 25
#
# Submitted batch job 41699895
# Running reconstruction for
# Chromosome:20, 5000000, 6950000
# Downsampling factor: 16
#
# Submitted batch job 41699896
# Running reconstruction for
# Chromosome:20, 5000000, 6950000
# Downsampling factor: 25
#
# Submitted batch job 41699897
# Running reconstruction for
# Chromosome:20, 43801000, 45710000
# Downsampling factor: 16
#
# Submitted batch job 41699899
# Running reconstruction for
# Chromosome:20, 43801000, 45710000
# Downsampling factor: 25
#
# Submitted batch job 41699900
# Running reconstruction for
# Chromosome:20, 47622000, 49500000
# Downsampling factor: 16
#
# Submitted batch job 41699901
# Running reconstruction for
# Chromosome:20, 47622000, 49500000
# Downsampling factor: 25
#
# Submitted batch job 41699902
# Running reconstruction for
# Chromosome:20, 45710000, 47620000
# Downsampling factor: 16
#
# Submitted batch job 41699903
# Running reconstruction for
# Chromosome:20, 45710000, 47620000
# Downsampling factor: 25

# %%
#Reconstructing matrices from ensambles per region

for region in my_regions:
    for ds in downsampling_factor:
        chrom, positions = region.split(':')
        chrom = chrom.replace('chr', '')
        start, end = map(int, positions.split('-'))
        print("Generating metrics for region:")
        print(chrom, start, end)
        print(f"With downsampling factor:{ds}")


        reconstruct.run_reconstruction(downsampling_factor=ds,
                                    lrf=20,
                                    run_option="whole",
                                    number_chains=n_chains,
                                    region_size = int(end - start),
                                    hic_res=hic_res,
                                    chromosome=str(chrom),
                                    start=start,
                                    cell_t=cell)
# Out:
# Generating metrics for region:
# 20 100000 2100000
# With downsampling factor:16
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '2000000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '100000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647421
# Generating metrics for region:
# 20 100000 2100000
# With downsampling factor:25
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '25', '-z', '2000000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '100000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647422
# Generating metrics for region:
# 20 100000 2100000
# With downsampling factor:50
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '50', '-z', '2000000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '100000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647423
# Generating metrics for region:
# 20 100000 2100000
# With downsampling factor:100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '100', '-z', '2000000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '100000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647424
# Generating metrics for region:
# 20 20000000 21500000
# With downsampling factor:16
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1500000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '20000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647425
# Generating metrics for region:
# 20 20000000 21500000
# With downsampling factor:25
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '25', '-z', '1500000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '20000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647426
# Generating metrics for region:
# 20 20000000 21500000
# With downsampling factor:50
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '50', '-z', '1500000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '20000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647427
# Generating metrics for region:
# 20 20000000 21500000
# With downsampling factor:100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '100', '-z', '1500000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '20000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647428
# Generating metrics for region:
# 20 42000000 43800000
# With downsampling factor:16
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1800000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '42000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647429
# Generating metrics for region:
# 20 42000000 43800000
# With downsampling factor:25
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '25', '-z', '1800000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '42000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647430
# Generating metrics for region:
# 20 42000000 43800000
# With downsampling factor:50
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '50', '-z', '1800000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '42000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647431
# Generating metrics for region:
# 20 42000000 43800000
# With downsampling factor:100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '100', '-z', '1800000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '42000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647432
# Generating metrics for region:
# 20 2100000 3800000
# With downsampling factor:16
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1700000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '2100000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647433
# Generating metrics for region:
# 20 2100000 3800000
# With downsampling factor:25
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '25', '-z', '1700000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '2100000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647434
# Generating metrics for region:
# 20 2100000 3800000
# With downsampling factor:50
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '50', '-z', '1700000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '2100000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647435
# Generating metrics for region:
# 20 2100000 3800000
# With downsampling factor:100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '100', '-z', '1700000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '2100000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647436
# Generating metrics for region:
# 20 5000000 6950000
# With downsampling factor:16
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1950000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '5000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647437
# Generating metrics for region:
# 20 5000000 6950000
# With downsampling factor:25
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '25', '-z', '1950000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '5000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647438
# Generating metrics for region:
# 20 5000000 6950000
# With downsampling factor:50
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '50', '-z', '1950000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '5000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647439
# Generating metrics for region:
# 20 5000000 6950000
# With downsampling factor:100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '100', '-z', '1950000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '5000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647440
# Generating metrics for region:
# 20 43801000 45710000
# With downsampling factor:16
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1909000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '43801000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647441
# Generating metrics for region:
# 20 43801000 45710000
# With downsampling factor:25
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '25', '-z', '1909000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '43801000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647442
# Generating metrics for region:
# 20 43801000 45710000
# With downsampling factor:50
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '50', '-z', '1909000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '43801000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647443
# Generating metrics for region:
# 20 43801000 45710000
# With downsampling factor:100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '100', '-z', '1909000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '43801000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647444
# Generating metrics for region:
# 20 47622000 49500000
# With downsampling factor:16
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1878000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '47622000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647445
# Generating metrics for region:
# 20 47622000 49500000
# With downsampling factor:25
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '25', '-z', '1878000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '47622000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647446
# Generating metrics for region:
# 20 47622000 49500000
# With downsampling factor:50
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '50', '-z', '1878000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '47622000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647447
# Generating metrics for region:
# 20 47622000 49500000
# With downsampling factor:100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '100', '-z', '1878000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '47622000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647448
# Generating metrics for region:
# 20 45710000 47620000
# With downsampling factor:16
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1910000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '45710000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647449
# Generating metrics for region:
# 20 45710000 47620000
# With downsampling factor:25
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '25', '-z', '1910000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '45710000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647450
# Generating metrics for region:
# 20 45710000 47620000
# With downsampling factor:50
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '50', '-z', '1910000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '45710000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647451
# Generating metrics for region:
# 20 45710000 47620000
# With downsampling factor:100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '100', '-z', '1910000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10005', '-c', '20', '-s', '45710000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41647452

# %% [markdown]
# ## Regions Different chromosomes

# %%
importlib.reload(utils)
# Out:
# <module 'src.utils' from '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/utils.py'>

# %%
chromosome_lengths_hg19 = {
    'chr1': 249250621,
    'chr2': 243199373,
    'chr3': 198022430,
    'chr4': 191154276,
    'chr5': 180915260,
    'chr6': 171115067,
    'chr7': 159138663,
    'chr8': 146364022,
    'chr9': 141213431,
    'chr10': 135534747,
    'chr11': 135006516,
    'chr12': 133851895,
    'chr13': 115169878,
    'chr14': 107349540,
    'chr15': 102531392,
    'chr16': 90354753,
    'chr17': 81195210,
    'chr18': 78077248,
    'chr19': 59128983,
    'chr20': 63025520,
    'chr21': 48129895,
    'chr22': 51304566,
    'chrX': 155270560,
    'chrY': 59373566
}

# %%
import random

def generate_regions(chr_num, num_regions, min_size=1_500_000, max_size=1_800_000):
    regions = []
    lengths_set = set()
    chr = "chr" + str(chr_num)
    chromosome_length = chromosome_lengths_hg19[chr]

    while len(regions) < num_regions:
        start = random.randint(1, chromosome_length - max_size)

        min_size_adjusted = (min_size + 49) // 50 * 50
        max_size_adjusted = max_size // 50 * 50

        num_intervals = (max_size_adjusted - min_size_adjusted) // 50 + 1

        random_interval = random.randint(0, num_intervals - 1)
        length = min_size_adjusted + random_interval * 50

        end = start + length

        if end > chromosome_length:
            end = chromosome_length

        #check if this length has already been used
        if length not in lengths_set:
            lengths_set.add(length)
            regions.append(f'{chr}:{start}-{end}')

    return regions

# %%
gen_reg = False # just once, we are saving the regions in a file so we can use them later
if gen_reg:
    for i in range(1,23):
        chromosome_selected = int(i)
        my_regions = generate_regions(chromosome_selected, 10)
        dir_cwd = os.path.join(os.getcwd(), "chr_regions")
        os.makedirs(dir_cwd, exist_ok=True)
        chromosome_regions = "regions_chr"+str(chromosome_selected)+".txt"
        chromosome_regions = os.path.join(dir_cwd, chromosome_regions)
        with open(chromosome_regions, 'w') as f:
            for item in my_regions:
                f.write("%s\n" % item)

        downsampling_factor = [16] # if we want to test more downsampling factors we can add them here
        n_chains = 10000
        cell = 'GM12878'
        hic_res = 10000

        for region in my_regions:
            chrom, positions = region.split(':')
            chrom = chrom.replace('chr', '')
            start, end = map(int, positions.split('-'))
            print("Generating data for region:")
            print(f"Chromosome:{chrom}, {start}, {end}")
            for ds in downsampling_factor:
                print(f"Downsampling factor: {ds}")
                utils.run_genData(
                chr=chromosome_selected,
                start=start,
                end=end,
                downsample_factor=ds,
                hic_res=hic_res, 
                lrbin=2,
                split_chains=False,
                file=globals.hic_file
            )
            print("Input data generated\n")

# %%
regions_dir="/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/chr_regions/"
regions_files = os.listdir(regions_dir)
regions_files.sort()

# %%
for i in regions_files:    

    my_regions = []
    with open(os.path.join(regions_dir,i), 'r') as file:
        for line in file:
            my_regions.append(line.strip())
            
    downsampling_factor = [16] # if we want to test more downsampling factors we can add them here
    for region in my_regions:
        chrom, positions = region.split(':')
        chrom = chrom.replace('chr', '')
        start, end = map(int, positions.split('-'))
        for ds in downsampling_factor:
            utils.run_pcSAC(
                chromosome=str("chr")+chrom,
                downsampling_factor=ds,
                lrf=20,
                run_option="whole",
                number_chains=n_chains,
                split_chains=False,
                region_size=int(end-start),
                hic_res=hic_res,
                cell=cell)
                
                print("Running reconstruction for")
                print(f"Chromosome:{chrom}, {start}, {end}")
                print(f"Downsampling factor: {ds}\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/mainFunctions_run.ipynb Cell 28 line 2
#      <a href='vscode-notebook-cell://ssh-remote%2Bint.nygenome.org/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/mainFunctions_run.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> start, end = map(int, positions.split('-'))
#      <a href='vscode-notebook-cell://ssh-remote%2Bint.nygenome.org/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/mainFunctions_run.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> for ds in downsampling_factor:
#      <a href='vscode-notebook-cell://ssh-remote%2Bint.nygenome.org/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/mainFunctions_run.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>     utils.run_pcSAC(
#      <a href='vscode-notebook-cell://ssh-remote%2Bint.nygenome.org/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/mainFunctions_run.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a>         chromosome=str("chr")+chrom,
#      <a href='vscode-notebook-cell://ssh-remote%2Bint.nygenome.org/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/mainFunctions_run.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>         downsampling_factor=ds,
#      <a href='vscode-notebook-cell://ssh-remote%2Bint.nygenome.org/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/mainFunctions_run.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a>         lrf=20,
#      <a href='vscode-notebook-cell://ssh-remote%2Bint.nygenome.org/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/mainFunctions_run.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a>         run_option="whole",
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bint.nygenome.org/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/mainFunctions_run.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a>         number_chains=n_chains,
#      <a href='vscode-notebook-cell://ssh-remote%2Bint.nygenome.org/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/mainFunctions_run.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a>         split_chains=False,
#      <a href='vscode-notebook-cell://ssh-remote%2Bint.nygenome.org/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/mainFunctions_run.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a>         region_size=int(end-start),
#      <a href='vscode-notebook-cell://ssh-remote%2Bint.nygenome.org/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/mainFunctions_run.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>         hic_res=hic_res,
#      <a href='vscode-notebook-cell://ssh-remote%2Bint.nygenome.org/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/mainFunctions_run.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>         cell=cell)
#      <a href='vscode-notebook-cell://ssh-remote%2Bint.nygenome.org/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/mainFunctions_run.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a>     print("Running reconstruction for")
#      <a href='vscode-notebook-cell://ssh-remote%2Bint.nygenome.org/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/mainFunctions_run.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a>     print(f"Chromosome:{chrom}, {start}, {end}")
#
# NameError: name 'n_chains' is not defined

# %%
for i in regions_files:    
    my_regions = []
    with open(os.path.join(regions_dir,i), 'r') as file:
        for line in file:
            my_regions.append(line.strip())
    downsampling_factor = [16] # if we want to test more downsampling factors we can add them here
    for region in my_regions:
        chrom, positions = region.split(':')
        chrom = chrom.replace('chr', '')
        start, end = map(int, positions.split('-'))
        print(chrom, start, end, int(end - start))
        reconstruct.run_reconstruction(downsampling_factor=int(16),
                                        lrf=20,
                                        run_option="whole",
                                        number_chains=10000,
                                        region_size = int(end - start),
                                        hic_res=10000,
                                        chromosome=chrom, #must be an int
                                        start=start)
# Out:
# regions_chr1.txt
# regions_chr10.txt
# 10 51460966 53161766 1700800
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1700800', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '10', '-s', '51460966', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880001
# 10 14897755 16422355 1524600
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1524600', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '10', '-s', '14897755', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880002
# 10 81888886 83675936 1787050
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1787050', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '10', '-s', '81888886', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880003
# 10 62704968 64456568 1751600
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1751600', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '10', '-s', '62704968', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880004
# 10 84867566 86505916 1638350
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1638350', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '10', '-s', '84867566', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880005
# 10 87304899 88855799 1550900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1550900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '10', '-s', '87304899', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880006
# 10 130122131 131901681 1779550
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1779550', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '10', '-s', '130122131', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880007
# 10 95780038 97534788 1754750
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1754750', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '10', '-s', '95780038', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880008
# 10 39780308 41332358 1552050
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1552050', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '10', '-s', '39780308', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880009
# 10 128643542 130302292 1658750
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1658750', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '10', '-s', '128643542', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880010
# regions_chr11.txt
# 11 107285762 108906062 1620300
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1620300', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '11', '-s', '107285762', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880011
# 11 123062545 124841445 1778900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1778900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '11', '-s', '123062545', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880012
# 11 131989456 133539206 1549750
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1549750', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '11', '-s', '131989456', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880013
# 11 69659982 71237432 1577450
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1577450', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '11', '-s', '69659982', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880014
# 11 5125025 6785575 1660550
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1660550', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '11', '-s', '5125025', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880015
# 11 59670465 61322615 1652150
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1652150', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '11', '-s', '59670465', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880016
# 11 101551311 103129311 1578000
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1578000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '11', '-s', '101551311', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880017
# 11 61132181 62778181 1646000
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1646000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '11', '-s', '61132181', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880018
# 11 105972779 107731629 1758850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1758850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '11', '-s', '105972779', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880019
# 11 10111908 11630158 1518250
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1518250', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '11', '-s', '10111908', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880020
# regions_chr12.txt
# 12 121054663 122571013 1516350
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1516350', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '12', '-s', '121054663', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880021
# 12 65251976 66856576 1604600
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1604600', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '12', '-s', '65251976', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880022
# 12 120939757 122450657 1510900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1510900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '12', '-s', '120939757', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880023
# 12 126806662 128519662 1713000
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1713000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '12', '-s', '126806662', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880024
# 12 89457613 91190763 1733150
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1733150', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '12', '-s', '89457613', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880025
# 12 76745271 78333721 1588450
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1588450', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '12', '-s', '76745271', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880026
# 12 30823805 32362055 1538250
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1538250', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '12', '-s', '30823805', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880027
# 12 104198946 105955896 1756950
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1756950', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '12', '-s', '104198946', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880028
# 12 104608722 106314472 1705750
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1705750', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '12', '-s', '104608722', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880029
# 12 93751410 95465910 1714500
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1714500', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '12', '-s', '93751410', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880030
# regions_chr13.txt
# 13 56386360 58094060 1707700
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1707700', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '13', '-s', '56386360', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880031
# 13 40978228 42524678 1546450
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1546450', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '13', '-s', '40978228', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880032
# 13 19554238 21228688 1674450
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1674450', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '13', '-s', '19554238', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880033
# 13 75968976 77641826 1672850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1672850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '13', '-s', '75968976', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880034
# 13 11278592 12821492 1542900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1542900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '13', '-s', '11278592', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880035
# 13 55786418 57312168 1525750
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1525750', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '13', '-s', '55786418', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880036
# 13 13315874 14985924 1670050
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1670050', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '13', '-s', '13315874', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880037
# 13 103860193 105424143 1563950
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1563950', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '13', '-s', '103860193', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880038
# 13 98553305 100065855 1512550
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1512550', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '13', '-s', '98553305', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880039
# 13 106212240 107895190 1682950
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1682950', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '13', '-s', '106212240', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880040
# regions_chr14.txt
# 14 57859426 59640576 1781150
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1781150', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '14', '-s', '57859426', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880041
# 14 55971412 57483712 1512300
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1512300', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '14', '-s', '55971412', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880042
# 14 66655849 68288749 1632900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1632900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '14', '-s', '66655849', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880043
# 14 96978050 98581500 1603450
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1603450', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '14', '-s', '96978050', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880044
# 14 10541265 12185615 1644350
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1644350', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '14', '-s', '10541265', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880045
# 14 9439462 10989162 1549700
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1549700', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '14', '-s', '9439462', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880046
# 14 48218164 50001514 1783350
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1783350', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '14', '-s', '48218164', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880047
# 14 3942983 5584433 1641450
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1641450', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '14', '-s', '3942983', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880048
# 14 46691359 48264209 1572850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1572850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '14', '-s', '46691359', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880049
# 14 1337378 2931778 1594400
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1594400', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '14', '-s', '1337378', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880050
# regions_chr15.txt
# 15 49097178 50626028 1528850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1528850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '15', '-s', '49097178', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880051
# 15 80072825 81631475 1558650
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1558650', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '15', '-s', '80072825', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880052
# 15 27914341 29415641 1501300
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1501300', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '15', '-s', '27914341', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880053
# 15 27486556 29256456 1769900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1769900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '15', '-s', '27486556', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880054
# 15 90430422 92230272 1799850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1799850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '15', '-s', '90430422', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880055
# 15 16534030 18036930 1502900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1502900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '15', '-s', '16534030', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880056
# 15 39361088 41012238 1651150
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1651150', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '15', '-s', '39361088', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880058
# 15 92538625 94048675 1510050
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1510050', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '15', '-s', '92538625', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880059
# 15 81181357 82776707 1595350
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1595350', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '15', '-s', '81181357', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880060
# 15 19043810 20620360 1576550
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1576550', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '15', '-s', '19043810', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880061
# regions_chr16.txt
# 16 60941301 62487301 1546000
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1546000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '16', '-s', '60941301', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880062
# 16 63980774 65621824 1641050
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1641050', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '16', '-s', '63980774', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880063
# 16 34657547 36210847 1553300
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1553300', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '16', '-s', '34657547', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880064
# 16 3749539 5334739 1585200
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1585200', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '16', '-s', '3749539', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880065
# 16 48619013 50256213 1637200
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1637200', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '16', '-s', '48619013', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880066
# 16 63534700 65154550 1619850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1619850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '16', '-s', '63534700', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880067
# 16 39774973 41501523 1726550
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1726550', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '16', '-s', '39774973', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880068
# 16 85351162 86985062 1633900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1633900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '16', '-s', '85351162', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880069
# 16 24702176 26445076 1742900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1742900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '16', '-s', '24702176', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880070
# 16 10846003 12388003 1542000
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1542000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '16', '-s', '10846003', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880071
# regions_chr17.txt
# 17 71568635 73306535 1737900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1737900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '17', '-s', '71568635', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880072
# 17 41307184 42871234 1564050
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1564050', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '17', '-s', '41307184', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880073
# 17 50544911 52105061 1560150
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1560150', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '17', '-s', '50544911', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880074
# 17 16808891 18400141 1591250
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1591250', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '17', '-s', '16808891', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880075
# 17 42398229 44106429 1708200
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1708200', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '17', '-s', '42398229', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880076
# 17 32593258 34190158 1596900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1596900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '17', '-s', '32593258', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880077
# 17 24688603 26307803 1619200
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1619200', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '17', '-s', '24688603', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880078
# 17 49990994 51662894 1671900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1671900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '17', '-s', '49990994', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880080
# 17 6208332 7762482 1554150
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1554150', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '17', '-s', '6208332', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880081
# 17 2758124 4419424 1661300
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1661300', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '17', '-s', '2758124', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880083
# regions_chr18.txt
# 18 10458396 12245996 1787600
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1787600', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '18', '-s', '10458396', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880084
# 18 9826235 11380285 1554050
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1554050', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '18', '-s', '9826235', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880085
# 18 56402545 58025145 1622600
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1622600', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '18', '-s', '56402545', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880087
# 18 73924062 75594762 1670700
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1670700', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '18', '-s', '73924062', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880089
# 18 19096965 20839065 1742100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1742100', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '18', '-s', '19096965', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880093
# 18 56665215 58287265 1622050
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1622050', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '18', '-s', '56665215', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880097
# 18 47588791 49123391 1534600
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1534600', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '18', '-s', '47588791', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880102
# 18 33293849 34975999 1682150
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1682150', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '18', '-s', '33293849', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880105
# 18 49560707 51321607 1760900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1760900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '18', '-s', '49560707', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880112
# 18 71029002 72552652 1523650
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1523650', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '18', '-s', '71029002', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880114
# regions_chr19.txt
# 19 25261908 26929258 1667350
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1667350', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '19', '-s', '25261908', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880127
# 19 565568 2236418 1670850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1670850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '19', '-s', '565568', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880133
# 19 48867367 50498667 1631300
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1631300', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '19', '-s', '48867367', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880138
# 19 29614967 31198517 1583550
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1583550', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '19', '-s', '29614967', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880140
# 19 24937425 26557525 1620100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1620100', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '19', '-s', '24937425', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880143
# 19 31600729 33137979 1537250
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1537250', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '19', '-s', '31600729', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880144
# 19 12445890 13990340 1544450
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1544450', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '19', '-s', '12445890', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880145
# 19 18587159 20133059 1545900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1545900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '19', '-s', '18587159', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880146
# 19 37458933 39206933 1748000
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1748000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '19', '-s', '37458933', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880147
# 19 46184341 47747341 1563000
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1563000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '19', '-s', '46184341', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880148
# regions_chr2.txt
# 2 58318555 59991805 1673250
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1673250', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '2', '-s', '58318555', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880149
# 2 22458182 24109032 1650850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1650850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '2', '-s', '22458182', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880150
# 2 59092807 60699657 1606850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1606850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '2', '-s', '59092807', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880151
# 2 157095942 158664142 1568200
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1568200', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '2', '-s', '157095942', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880152
# 2 115755013 117333613 1578600
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1578600', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '2', '-s', '115755013', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880153
# 2 96239583 97786683 1547100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1547100', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '2', '-s', '96239583', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880154
# 2 17141737 18929237 1787500
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1787500', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '2', '-s', '17141737', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880155
# 2 7413906 9129256 1715350
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1715350', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '2', '-s', '7413906', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880156
# 2 121228617 123005867 1777250
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1777250', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '2', '-s', '121228617', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880157
# 2 54140189 55688889 1548700
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1548700', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '2', '-s', '54140189', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880158
# regions_chr20.txt
# 20 53395648 55183398 1787750
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1787750', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '53395648', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880159
# 20 29941585 31604885 1663300
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1663300', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '29941585', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880160
# 20 12440688 14113388 1672700
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1672700', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '12440688', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880161
# 20 28972004 30543554 1571550
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1571550', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '28972004', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880162
# 20 16640158 18325858 1685700
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1685700', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '16640158', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880163
# 20 22843046 24557396 1714350
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1714350', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '22843046', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880164
# 20 9567543 11213093 1645550
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1645550', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '9567543', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880165
# 20 31033512 32792162 1758650
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1758650', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '31033512', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880166
# 20 42768716 44304116 1535400
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1535400', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '42768716', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880167
# 20 32432908 34016308 1583400
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1583400', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '32432908', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880168
# regions_chr21.txt
# 21 19778884 21279634 1500750
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1500750', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '21', '-s', '19778884', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880169
# 21 30137811 31891211 1753400
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1753400', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '21', '-s', '30137811', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880170
# 21 31005024 32508174 1503150
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1503150', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '21', '-s', '31005024', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880171
# 21 14679003 16301253 1622250
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1622250', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '21', '-s', '14679003', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880172
# 21 7681095 9438695 1757600
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1757600', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '21', '-s', '7681095', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880173
# 21 20210437 21933737 1723300
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1723300', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '21', '-s', '20210437', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880174
# 21 40880072 42444022 1563950
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1563950', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '21', '-s', '40880072', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880175
# 21 28468189 30257439 1789250
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1789250', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '21', '-s', '28468189', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880176
# 21 31637463 33175363 1537900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1537900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '21', '-s', '31637463', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880177
# 21 45511806 47215606 1703800
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1703800', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '21', '-s', '45511806', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880178
# regions_chr22.txt
# 22 15593599 17316299 1722700
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1722700', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '22', '-s', '15593599', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880179
# 22 27199566 28814266 1614700
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1614700', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '22', '-s', '27199566', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880180
# 22 42417205 43926055 1508850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1508850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '22', '-s', '42417205', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880181
# 22 8108873 9719473 1610600
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1610600', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '22', '-s', '8108873', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880182
# 22 44861516 46378116 1516600
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1516600', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '22', '-s', '44861516', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880183
# 22 16993 1622043 1605050
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1605050', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '22', '-s', '16993', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880184
# 22 26738092 28453542 1715450
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1715450', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '22', '-s', '26738092', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880185
# 22 39031602 40822402 1790800
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1790800', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '22', '-s', '39031602', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880186
# 22 26590880 28272980 1682100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1682100', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '22', '-s', '26590880', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880187
# 22 6847234 8450684 1603450
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1603450', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '22', '-s', '6847234', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880188
# regions_chr3.txt
# 3 133435903 135098903 1663000
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1663000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '3', '-s', '133435903', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880189
# 3 68848239 70433089 1584850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1584850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '3', '-s', '68848239', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880190
# 3 172066396 173583596 1517200
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1517200', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '3', '-s', '172066396', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880191
# 3 57953703 59709053 1755350
# ...
# 5 39826932 41432132 1605200
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1605200', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '5', '-s', '39826932', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880211
# 5 161755640 163319490 1563850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1563850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '5', '-s', '161755640', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880212
# 5 101738409 103477159 1738750
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1738750', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '5', '-s', '101738409', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880213
# 5 79022660 80816760 1794100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1794100', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '5', '-s', '79022660', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880214
# 5 126280463 127807613 1527150
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1527150', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '5', '-s', '126280463', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880215
# 5 22721219 24432769 1711550
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1711550', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '5', '-s', '22721219', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880216
# 5 60422313 61975763 1553450
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1553450', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '5', '-s', '60422313', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880217
# 5 10907077 12530127 1623050
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1623050', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '5', '-s', '10907077', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880218
# regions_chr6.txt
# 6 4103073 5786773 1683700
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1683700', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '6', '-s', '4103073', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880219
# 6 88743249 90309049 1565800
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1565800', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '6', '-s', '88743249', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880220
# 6 39948428 41717128 1768700
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1768700', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '6', '-s', '39948428', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880221
# 6 123677635 125329685 1652050
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1652050', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '6', '-s', '123677635', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880222
# 6 135559824 137216374 1656550
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1656550', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '6', '-s', '135559824', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880223
# 6 142219161 143924911 1705750
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1705750', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '6', '-s', '142219161', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880224
# 6 9024267 10759317 1735050
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1735050', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '6', '-s', '9024267', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880225
# 6 24332839 26110739 1777900
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1777900', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '6', '-s', '24332839', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880226
# 6 139049125 140794925 1745800
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1745800', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '6', '-s', '139049125', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880227
# 6 20497223 22171823 1674600
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1674600', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '6', '-s', '20497223', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880228
# regions_chr7.txt
# 7 55325845 56944445 1618600
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1618600', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '7', '-s', '55325845', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880229
# 7 143724720 145469870 1745150
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1745150', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '7', '-s', '143724720', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880230
# 7 112163246 113860746 1697500
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1697500', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '7', '-s', '112163246', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880231
# 7 104305668 106054468 1748800
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1748800', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '7', '-s', '104305668', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880232
# 7 62698764 64207114 1508350
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1508350', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '7', '-s', '62698764', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880233
# 7 64612 1639112 1574500
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1574500', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '7', '-s', '64612', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880234
# 7 81186169 82893769 1707600
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1707600', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '7', '-s', '81186169', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880235
# 7 153079785 154683985 1604200
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1604200', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '7', '-s', '153079785', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880236
# 7 89304669 90831519 1526850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1526850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '7', '-s', '89304669', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880237
# 7 132475588 134082888 1607300
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1607300', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '7', '-s', '132475588', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880238
# regions_chr8.txt
# 8 81283565 82950665 1667100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1667100', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '8', '-s', '81283565', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880239
# 8 103122092 104779242 1657150
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1657150', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '8', '-s', '103122092', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880240
# 8 16712460 18279510 1567050
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1567050', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '8', '-s', '16712460', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880241
# 8 34177422 35775272 1597850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1597850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '8', '-s', '34177422', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880242
# 8 77064690 78863440 1798750
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1798750', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '8', '-s', '77064690', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880243
# 8 89664060 91186760 1522700
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1522700', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '8', '-s', '89664060', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880244
# 8 9645916 11343066 1697150
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1697150', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '8', '-s', '9645916', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880245
# 8 112170063 113727763 1557700
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1557700', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '8', '-s', '112170063', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880246
# 8 132024868 133771418 1746550
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1746550', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '8', '-s', '132024868', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880247
# 8 21909605 23685455 1775850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1775850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '8', '-s', '21909605', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880248
# regions_chr9.txt
# 9 40634087 42278537 1644450
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1644450', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '9', '-s', '40634087', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880249
# 9 110364607 111879007 1514400
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1514400', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '9', '-s', '110364607', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880250
# 9 125165805 126824155 1658350
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1658350', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '9', '-s', '125165805', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880251
# 9 123180290 124699540 1519250
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1519250', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '9', '-s', '123180290', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880252
# 9 27240967 28933817 1692850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1692850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '9', '-s', '27240967', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880253
# 9 40632473 42140723 1508250
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1508250', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '9', '-s', '40632473', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880254
# 9 8714882 10459932 1745050
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1745050', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '9', '-s', '8714882', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880255
# 9 35621910 37379910 1758000
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1758000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '9', '-s', '35621910', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880256
# 9 86949293 88492393 1543100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1543100', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '9', '-s', '86949293', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880257
# 9 93057978 94637828 1579850
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1579850', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '9', '-s', '93057978', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41880258

# %% [markdown]
# ## 10kb resolution workflow 4:1

# %%
importlib.reload(utils)
# Out:
# <module 'src.utils' from '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/utils.py'>

# %%
# Generate data for each region

my_regions = [ 
              'chr20:2100000-3800000',
              'chr20:47622000-49500000',
              ]

downsampling_factor = [16,25,50,100] 
n_chains = 10000
cell = 'GM12878'
hic_res = 10000

for region in my_regions:
    chrom, positions = region.split(':')
    chrom = chrom.replace('chr', '')
    start, end = map(int, positions.split('-'))
    print("Generating data for region:")
    print(f"Chromosome:{chrom}, {start}, {end}")
    for ds in downsampling_factor:
        print(f"Downsampling factor: {ds}")
        utils.run_genData(
        chr=globals.chromosome,
        start=start,
        end=end,
        downsample_factor=ds,
        hic_res=hic_res, 
        lrbin=4,
        split_chains=False,
        file=globals.hic_file
    )
    print("Input data generated\n")
# Out:
# Generating data for region:
# Chromosome:20, 2100000, 3800000
# Downsampling factor: 16
# Submitted batch job 41698339
# Downsampling factor: 25
# Submitted batch job 41698340
# Downsampling factor: 50
# Submitted batch job 41698341
# Downsampling factor: 100
# Submitted batch job 41698342
# Input data generated
#
# Generating data for region:
# Chromosome:20, 47622000, 49500000
# Downsampling factor: 16
# Submitted batch job 41698343
# Downsampling factor: 25
# Submitted batch job 41698344
# Downsampling factor: 50
# Submitted batch job 41698345
# Downsampling factor: 100
# Submitted batch job 41698346
# Input data generated

# %%
for region in my_regions:
    chrom, positions = region.split(':')
    chrom = chrom.replace('chr', '')
    start, end = map(int, positions.split('-'))
    for ds in downsampling_factor:
        utils.run_pcSAC(
            downsampling_factor=ds,
            lrf=40,
            run_option="whole",
            number_chains=n_chains,
            split_chains=False,
            region_size=int(end-start),
            hic_res=hic_res,
            cell=cell)
        
        print("Running reconstruction for")
        print(f"Chromosome:{chrom}, {start}, {end}")
        print(f"Downsampling factor: {ds}\n")
# Out:
# Submitted batch job 41698349
# Running reconstruction for
# Chromosome:20, 2100000, 3800000
# Downsampling factor: 16
#
# Submitted batch job 41698350
# Running reconstruction for
# Chromosome:20, 2100000, 3800000
# Downsampling factor: 25
#
# Submitted batch job 41698351
# Running reconstruction for
# Chromosome:20, 2100000, 3800000
# Downsampling factor: 50
#
# Submitted batch job 41698352
# Running reconstruction for
# Chromosome:20, 2100000, 3800000
# Downsampling factor: 100
#
# Submitted batch job 41698353
# Running reconstruction for
# Chromosome:20, 47622000, 49500000
# Downsampling factor: 16
#
# Submitted batch job 41698354
# Running reconstruction for
# Chromosome:20, 47622000, 49500000
# Downsampling factor: 25
#
# Submitted batch job 41698355
# Running reconstruction for
# Chromosome:20, 47622000, 49500000
# Downsampling factor: 50
#
# Submitted batch job 41698356
# Running reconstruction for
# Chromosome:20, 47622000, 49500000
# Downsampling factor: 100

# %%
my_regions
# Out:
# ['chr20:2100000-3800000', 'chr20:47622000-49500000']

# %%
for region in my_regions:
    for ds in downsampling_factor:
        chrom, positions = region.split(':')
        chrom = chrom.replace('chr', '')
        start, end = map(int, positions.split('-'))
        print("Generating metrics for region:")
        print(chrom, start, end)
        print(f"With downsampling factor:{ds}")


        reconstruct.run_reconstruction(downsampling_factor=ds,
                                    lrf=40,
                                    run_option="whole",
                                    number_chains=n_chains,
                                    region_size = int(end - start),
                                    hic_res=hic_res,
                                    chromosome=str(chrom),
                                    start=start,
                                    cell_t=cell)
# Out:
# Generating metrics for region:
# 20 2100000 3800000
# With downsampling factor:16
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1700000', '-h', '10000', '-l', '40', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '2100000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41699317
# Generating metrics for region:
# 20 2100000 3800000
# With downsampling factor:25
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '25', '-z', '1700000', '-h', '10000', '-l', '40', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '2100000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41699318
# Generating metrics for region:
# 20 2100000 3800000
# With downsampling factor:50
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '50', '-z', '1700000', '-h', '10000', '-l', '40', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '2100000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41699319
# Generating metrics for region:
# 20 2100000 3800000
# With downsampling factor:100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '100', '-z', '1700000', '-h', '10000', '-l', '40', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '2100000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41699320
# Generating metrics for region:
# 20 47622000 49500000
# With downsampling factor:16
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1878000', '-h', '10000', '-l', '40', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '47622000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41699321
# Generating metrics for region:
# 20 47622000 49500000
# With downsampling factor:25
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '25', '-z', '1878000', '-h', '10000', '-l', '40', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '47622000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41699322
# Generating metrics for region:
# 20 47622000 49500000
# With downsampling factor:50
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '50', '-z', '1878000', '-h', '10000', '-l', '40', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '47622000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41699323
# Generating metrics for region:
# 20 47622000 49500000
# With downsampling factor:100
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '100', '-z', '1878000', '-h', '10000', '-l', '40', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '47622000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41699324

# %% [markdown]
# ### Synthetic data as gold standard

# %% [markdown]
# This section is dedicated only to the analysis of synth data by different downsamples

# %%
sys.path.append('../synthetic/')
from synth_src import utils as synth_utils
from synth_src import globals as synth_globals
importlib.reload(synth_utils)
importlib.reload(synth_globals)
# Out:
# <module 'synth_src.globals' from '/gpfs/commons/groups/gursoy_lab/cangel/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/src/../synthetic/synth_src/globals.py'>

# %% [markdown]
# Generating gold standard synthetic matrix

# %%
#Generating synthetic data
synth_utils.generate_synthetic_chains(monomers = 200, cells = 10000, type="COMPLEX", dc=1500)
# Out:
# Running synthetic chain generation with the following parameters:
# CMD:  sbatch /gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/synthetic/generate_chains.sh 200 10000 1500 COMPLEX chains_200-monomers_10000-cells_1500-dc_COMPLEX
# Number of monomers:  200
# Number of cells:  10000
# Interaction distance:  1500
# Type of chain:  COMPLEX
# Output directory:  /gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/results/synthetic/chains_200-monomers_10000-cells_1500-dc_COMPLEX
# Success in generating synthetic chains: b'Submitted batch job 41590376\n'
# 0

# %% [markdown]
# Downsampling generated chains to create LR matrices (input)

# %%
chains_downsample_factors = [100,250,1000,2500,3750,5000]
for ds in chains_downsample_factors:
    print(f"Downsampling: {ds} chains")

    synth_utils.downsample_synthetic_chains(all_chains=10000,
                                            chains_sample=ds)
    
    print(f"Generating 3D ensambles with downsampled chains: {ds}")
    
    synth_utils.pcSAC_synthetic(downsampled_chains=ds,
                                run_option="whole",
                                number_chains=10000,
                                split_chains=False)
# Out:
# Downsampling: 100 chains
# Computing HR contact map 1
# Computing HR contact map 2
# Computing HR contact map 3
# Computing HR contact map 4
# Computing HR contact map 5
# Computing HR contact map 6
# Computing HR contact map 7
# Computing HR contact map 8
# Computing HR contact map 9
# Computing HR contact map 10
# Computing HR contact map 11
# Computing HR contact map 12
# Computing HR contact map 13
# Computing HR contact map 14
# Computing HR contact map 15
# Computing HR contact map 16
# Computing HR contact map 17
# Computing HR contact map 18
# Computing HR contact map 19
# Computing HR contact map 20
# Computing HR contact map 21
# Computing HR contact map 22
# Computing HR contact map 23
# Computing HR contact map 24
# Computing HR contact map 25
# Computing HR contact map 26
# Computing HR contact map 27
# Computing HR contact map 28
# Computing HR contact map 29
# Computing HR contact map 30
# Computing HR contact map 31
# Computing HR contact map 32
# Computing HR contact map 33
# Computing HR contact map 34
# Computing HR contact map 35
# Computing HR contact map 36
# Computing HR contact map 37
# Computing HR contact map 38
# Computing HR contact map 39
# Computing HR contact map 40
# Computing HR contact map 41
# Computing HR contact map 42
# Computing HR contact map 43
# Computing HR contact map 44
# Computing HR contact map 45
# Computing HR contact map 46
# Computing HR contact map 47
# Computing HR contact map 48
# Computing HR contact map 49
# Computing HR contact map 50
# Computing HR contact map 51
# Computing HR contact map 52
# Computing HR contact map 53
# Computing HR contact map 54
# Computing HR contact map 55
# Computing HR contact map 56
# Computing HR contact map 57
# Computing HR contact map 58
# Computing HR contact map 59
# Computing HR contact map 60
# Computing HR contact map 61
# Computing HR contact map 62
# Computing HR contact map 63
# Computing HR contact map 64
# Computing HR contact map 65
# Computing HR contact map 66
# Computing HR contact map 67
# Computing HR contact map 68
# Computing HR contact map 69
# Computing HR contact map 70
# Computing HR contact map 71
# Computing HR contact map 72
# Computing HR contact map 73
# Computing HR contact map 74
# Computing HR contact map 75
# Computing HR contact map 76
# Computing HR contact map 77
# Computing HR contact map 78
# Computing HR contact map 79
# Computing HR contact map 80
# Computing HR contact map 81
# Computing HR contact map 82
# Computing HR contact map 83
# Computing HR contact map 84
# Computing HR contact map 85
# Computing HR contact map 86
# Computing HR contact map 87
# Computing HR contact map 88
# Computing HR contact map 89
# Computing HR contact map 90
# Computing HR contact map 91
# Computing HR contact map 92
# Computing HR contact map 93
# Computing HR contact map 94
# Computing HR contact map 95
# Computing HR contact map 96
# Computing HR contact map 97
# Computing HR contact map 98
# Computing HR contact map 99
# Computing HR contact map 100
# All distance maps retrieved
# Computing global LR contact map
# 50 1225 200
# Generating 3D ensambles with downsampled chains: 100
# Submitted batch job 41592211
# Downsampling: 250 chains
# Computing HR contact map 1
# Computing HR contact map 2
# Computing HR contact map 3
# Computing HR contact map 4
# Computing HR contact map 5
# Computing HR contact map 6
# Computing HR contact map 7
# Computing HR contact map 8
# Computing HR contact map 9
# Computing HR contact map 10
# Computing HR contact map 11
# Computing HR contact map 12
# Computing HR contact map 13
# Computing HR contact map 14
# Computing HR contact map 15
# Computing HR contact map 16
# Computing HR contact map 17
# Computing HR contact map 18
# Computing HR contact map 19
# Computing HR contact map 20
# Computing HR contact map 21
# Computing HR contact map 22
# Computing HR contact map 23
# Computing HR contact map 24
# Computing HR contact map 25
# Computing HR contact map 26
# Computing HR contact map 27
# Computing HR contact map 28
# Computing HR contact map 29
# Computing HR contact map 30
# Computing HR contact map 31
# Computing HR contact map 32
# Computing HR contact map 33
# Computing HR contact map 34
# Computing HR contact map 35
# Computing HR contact map 36
# Computing HR contact map 37
# Computing HR contact map 38
# Computing HR contact map 39
# Computing HR contact map 40
# Computing HR contact map 41
# Computing HR contact map 42
# Computing HR contact map 43
# Computing HR contact map 44
# Computing HR contact map 45
# Computing HR contact map 46
# Computing HR contact map 47
# Computing HR contact map 48
# Computing HR contact map 49
# Computing HR contact map 50
# Computing HR contact map 51
# Computing HR contact map 52
# Computing HR contact map 53
# Computing HR contact map 54
# Computing HR contact map 55
# Computing HR contact map 56
# Computing HR contact map 57
# Computing HR contact map 58
# Computing HR contact map 59
# Computing HR contact map 60
# Computing HR contact map 61
# Computing HR contact map 62
# Computing HR contact map 63
# Computing HR contact map 64
# Computing HR contact map 65
# Computing HR contact map 66
# Computing HR contact map 67
# Computing HR contact map 68
# Computing HR contact map 69
# Computing HR contact map 70
# Computing HR contact map 71
# Computing HR contact map 72
# Computing HR contact map 73
# Computing HR contact map 74
# Computing HR contact map 75
# Computing HR contact map 76
# Computing HR contact map 77
# Computing HR contact map 78
# Computing HR contact map 79
# Computing HR contact map 80
# Computing HR contact map 81
# Computing HR contact map 82
# Computing HR contact map 83
# Computing HR contact map 84
# Computing HR contact map 85
# Computing HR contact map 86
# Computing HR contact map 87
# Computing HR contact map 88
# Computing HR contact map 89
# Computing HR contact map 90
# Computing HR contact map 91
# Computing HR contact map 92
# Computing HR contact map 93
# Computing HR contact map 94
# Computing HR contact map 95
# Computing HR contact map 96
# Computing HR contact map 97
# Computing HR contact map 98
# Computing HR contact map 99
# Computing HR contact map 100
# Computing HR contact map 101
# Computing HR contact map 102
# Computing HR contact map 103
# Computing HR contact map 104
# Computing HR contact map 105
# Computing HR contact map 106
# Computing HR contact map 107
# Computing HR contact map 108
# Computing HR contact map 109
# Computing HR contact map 110
# Computing HR contact map 111
# Computing HR contact map 112
# Computing HR contact map 113
# Computing HR contact map 114
# Computing HR contact map 115
# Computing HR contact map 116
# Computing HR contact map 117
# Computing HR contact map 118
# Computing HR contact map 119
# Computing HR contact map 120
# Computing HR contact map 121
# Computing HR contact map 122
# Computing HR contact map 123
# Computing HR contact map 124
# Computing HR contact map 125
# Computing HR contact map 126
# Computing HR contact map 127
# Computing HR contact map 128
# Computing HR contact map 129
# Computing HR contact map 130
# Computing HR contact map 131
# Computing HR contact map 132
# Computing HR contact map 133
# Computing HR contact map 134
# Computing HR contact map 135
# Computing HR contact map 136
# Computing HR contact map 137
# Computing HR contact map 138
# Computing HR contact map 139
# Computing HR contact map 140
# Computing HR contact map 141
# Computing HR contact map 142
# Computing HR contact map 143
# Computing HR contact map 144
# Computing HR contact map 145
# Computing HR contact map 146
# Computing HR contact map 147
# Computing HR contact map 148
# Computing HR contact map 149
# Computing HR contact map 150
# Computing HR contact map 151
# Computing HR contact map 152
# Computing HR contact map 153
# Computing HR contact map 154
# Computing HR contact map 155
# Computing HR contact map 156
# Computing HR contact map 157
# Computing HR contact map 158
# Computing HR contact map 159
# Computing HR contact map 160
# Computing HR contact map 161
# Computing HR contact map 162
# Computing HR contact map 163
# Computing HR contact map 164
# Computing HR contact map 165
# Computing HR contact map 166
# Computing HR contact map 167
# Computing HR contact map 168
# Computing HR contact map 169
# Computing HR contact map 170
# Computing HR contact map 171
# Computing HR contact map 172
# Computing HR contact map 173
# Computing HR contact map 174
# Computing HR contact map 175
# Computing HR contact map 176
# Computing HR contact map 177
# Computing HR contact map 178
# Computing HR contact map 179
# Computing HR contact map 180
# Computing HR contact map 181
# Computing HR contact map 182
# Computing HR contact map 183
# Computing HR contact map 184
# Computing HR contact map 185
# Computing HR contact map 186
# Computing HR contact map 187
# Computing HR contact map 188
# Computing HR contact map 189
# Computing HR contact map 190
# Computing HR contact map 191
# Computing HR contact map 192
# Computing HR contact map 193
# Computing HR contact map 194
# Computing HR contact map 195
# Computing HR contact map 196
# Computing HR contact map 197
# Computing HR contact map 198
# Computing HR contact map 199
# Computing HR contact map 200
# Computing HR contact map 201
# Computing HR contact map 202
# Computing HR contact map 203
# Computing HR contact map 204
# Computing HR contact map 205
# Computing HR contact map 206
# Computing HR contact map 207
# Computing HR contact map 208
# Computing HR contact map 209
# Computing HR contact map 210
# Computing HR contact map 211
# Computing HR contact map 212
# Computing HR contact map 213
# Computing HR contact map 214
# Computing HR contact map 215
# Computing HR contact map 216
# Computing HR contact map 217
# Computing HR contact map 218
# Computing HR contact map 219
# Computing HR contact map 220
# Computing HR contact map 221
# Computing HR contact map 222
# Computing HR contact map 223
# Computing HR contact map 224
# Computing HR contact map 225
# Computing HR contact map 226
# Computing HR contact map 227
# Computing HR contact map 228
# Computing HR contact map 229
# Computing HR contact map 230
# Computing HR contact map 231
# Computing HR contact map 232
# Computing HR contact map 233
# Computing HR contact map 234
# Computing HR contact map 235
# Computing HR contact map 236
# Computing HR contact map 237
# Computing HR contact map 238
# Computing HR contact map 239
# Computing HR contact map 240
# Computing HR contact map 241
# Computing HR contact map 242
# Computing HR contact map 243
# Computing HR contact map 244
# Computing HR contact map 245
# Computing HR contact map 246
# Computing HR contact map 247
# Computing HR contact map 248
# Computing HR contact map 249
# Computing HR contact map 250
# All distance maps retrieved
# Computing global LR contact map
# 50 1225 200
# Generating 3D ensambles with downsampled chains: 250
# Submitted batch job 41592229
# Downsampling: 1000 chains
# Computing HR contact map 1
# Computing HR contact map 2
# Computing HR contact map 3
# Computing HR contact map 4
# Computing HR contact map 5
# Computing HR contact map 6
# Computing HR contact map 7
# Computing HR contact map 8
# Computing HR contact map 9
# Computing HR contact map 10
# Computing HR contact map 11
# Computing HR contact map 12
# Computing HR contact map 13
# Computing HR contact map 14
# Computing HR contact map 15
# Computing HR contact map 16
# Computing HR contact map 17
# Computing HR contact map 18
# Computing HR contact map 19
# Computing HR contact map 20
# Computing HR contact map 21
# Computing HR contact map 22
# Computing HR contact map 23
# Computing HR contact map 24
# Computing HR contact map 25
# Computing HR contact map 26
# Computing HR contact map 27
# Computing HR contact map 28
# Computing HR contact map 29
# Computing HR contact map 30
# Computing HR contact map 31
# Computing HR contact map 32
# Computing HR contact map 33
# Computing HR contact map 34
# Computing HR contact map 35
# Computing HR contact map 36
# Computing HR contact map 37
# Computing HR contact map 38
# Computing HR contact map 39
# Computing HR contact map 40
# Computing HR contact map 41
# Computing HR contact map 42
# Computing HR contact map 43
# Computing HR contact map 44
# Computing HR contact map 45
# Computing HR contact map 46
# Computing HR contact map 47
# Computing HR contact map 48
# Computing HR contact map 49
# Computing HR contact map 50
# Computing HR contact map 51
# Computing HR contact map 52
# Computing HR contact map 53
# Computing HR contact map 54
# Computing HR contact map 55
# Computing HR contact map 56
# Computing HR contact map 57
# Computing HR contact map 58
# Computing HR contact map 59
# Computing HR contact map 60
# Computing HR contact map 61
# Computing HR contact map 62
# Computing HR contact map 63
# Computing HR contact map 64
# Computing HR contact map 65
# Computing HR contact map 66
# Computing HR contact map 67
# Computing HR contact map 68
# Computing HR contact map 69
# Computing HR contact map 70
# Computing HR contact map 71
# Computing HR contact map 72
# Computing HR contact map 73
# Computing HR contact map 74
# Computing HR contact map 75
# Computing HR contact map 76
# Computing HR contact map 77
# Computing HR contact map 78
# Computing HR contact map 79
# Computing HR contact map 80
# Computing HR contact map 81
# Computing HR contact map 82
# Computing HR contact map 83
# Computing HR contact map 84
# Computing HR contact map 85
# Computing HR contact map 86
# Computing HR contact map 87
# Computing HR contact map 88
# Computing HR contact map 89
# Computing HR contact map 90
# Computing HR contact map 91
# Computing HR contact map 92
# Computing HR contact map 93
# Computing HR contact map 94
# Computing HR contact map 95
# Computing HR contact map 96
# Computing HR contact map 97
# Computing HR contact map 98
# Computing HR contact map 99
# Computing HR contact map 100
# Computing HR contact map 101
# Computing HR contact map 102
# Computing HR contact map 103
# Computing HR contact map 104
# Computing HR contact map 105
# Computing HR contact map 106
# Computing HR contact map 107
# Computing HR contact map 108
# Computing HR contact map 109
# Computing HR contact map 110
# Computing HR contact map 111
# Computing HR contact map 112
# Computing HR contact map 113
# Computing HR contact map 114
# Computing HR contact map 115
# Computing HR contact map 116
# Computing HR contact map 117
# Computing HR contact map 118
# Computing HR contact map 119
# Computing HR contact map 120
# Computing HR contact map 121
# Computing HR contact map 122
# Computing HR contact map 123
# Computing HR contact map 124
# Computing HR contact map 125
# Computing HR contact map 126
# Computing HR contact map 127
# Computing HR contact map 128
# Computing HR contact map 129
# Computing HR contact map 130
# Computing HR contact map 131
# Computing HR contact map 132
# Computing HR contact map 133
# Computing HR contact map 134
# Computing HR contact map 135
# Computing HR contact map 136
# Computing HR contact map 137
# Computing HR contact map 138
# Computing HR contact map 139
# Computing HR contact map 140
# Computing HR contact map 141
# Computing HR contact map 142
# Computing HR contact map 143
# Computing HR contact map 144
# Computing HR contact map 145
# Computing HR contact map 146
# Computing HR contact map 147
# Computing HR contact map 148
# Computing HR contact map 149
# Computing HR contact map 150
# Computing HR contact map 151
# Computing HR contact map 152
# Computing HR contact map 153
# Computing HR contact map 154
# Computing HR contact map 155
# Computing HR contact map 156
# Computing HR contact map 157
# Computing HR contact map 158
# Computing HR contact map 159
# Computing HR contact map 160
# Computing HR contact map 161
# Computing HR contact map 162
# Computing HR contact map 163
# Computing HR contact map 164
# Computing HR contact map 165
# Computing HR contact map 166
# Computing HR contact map 167
# Computing HR contact map 168
# Computing HR contact map 169
# Computing HR contact map 170
# Computing HR contact map 171
# Computing HR contact map 172
# Computing HR contact map 173
# Computing HR contact map 174
# Computing HR contact map 175
# Computing HR contact map 176
# Computing HR contact map 177
# Computing HR contact map 178
# Computing HR contact map 179
# Computing HR contact map 180
# Computing HR contact map 181
# Computing HR contact map 182
# Computing HR contact map 183
# Computing HR contact map 184
# Computing HR contact map 185
# Computing HR contact map 186
# Computing HR contact map 187
# Computing HR contact map 188
# Computing HR contact map 189
# Computing HR contact map 190
# Computing HR contact map 191
# Computing HR contact map 192
# Computing HR contact map 193
# Computing HR contact map 194
# Computing HR contact map 195
# Computing HR contact map 196
# Computing HR contact map 197
# Computing HR contact map 198
# Computing HR contact map 199
# Computing HR contact map 200
# Computing HR contact map 201
# Computing HR contact map 202
# Computing HR contact map 203
# Computing HR contact map 204
# Computing HR contact map 205
# Computing HR contact map 206
# Computing HR contact map 207
# Computing HR contact map 208
# Computing HR contact map 209
# Computing HR contact map 210
# Computing HR contact map 211
# Computing HR contact map 212
# Computing HR contact map 213
# Computing HR contact map 214
# Computing HR contact map 215
# Computing HR contact map 216
# Computing HR contact map 217
# Computing HR contact map 218
# Computing HR contact map 219
# Computing HR contact map 220
# Computing HR contact map 221
# Computing HR contact map 222
# Computing HR contact map 223
# Computing HR contact map 224
# Computing HR contact map 225
# Computing HR contact map 226
# Computing HR contact map 227
# Computing HR contact map 228
# Computing HR contact map 229
# Computing HR contact map 230
# Computing HR contact map 231
# Computing HR contact map 232
# Computing HR contact map 233
# Computing HR contact map 234
# Computing HR contact map 235
# Computing HR contact map 236
# Computing HR contact map 237
# Computing HR contact map 238
# Computing HR contact map 239
# Computing HR contact map 240
# Computing HR contact map 241
# Computing HR contact map 242
# Computing HR contact map 243
# Computing HR contact map 244
# Computing HR contact map 245
# Computing HR contact map 246
# Computing HR contact map 247
# Computing HR contact map 248
# Computing HR contact map 249
# Computing HR contact map 250
# Computing HR contact map 251
# Computing HR contact map 252
# Computing HR contact map 253
# Computing HR contact map 254
# Computing HR contact map 255
# Computing HR contact map 256
# Computing HR contact map 257
# Computing HR contact map 258
# Computing HR contact map 259
# Computing HR contact map 260
# Computing HR contact map 261
# Computing HR contact map 262
# Computing HR contact map 263
# Computing HR contact map 264
# Computing HR contact map 265
# Computing HR contact map 266
# Computing HR contact map 267
# Computing HR contact map 268
# Computing HR contact map 269
# Computing HR contact map 270
# Computing HR contact map 271
# Computing HR contact map 272
# Computing HR contact map 273
# Computing HR contact map 274
# Computing HR contact map 275
# Computing HR contact map 276
# Computing HR contact map 277
# Computing HR contact map 278
# Computing HR contact map 279
# Computing HR contact map 280
# Computing HR contact map 281
# Computing HR contact map 282
# Computing HR contact map 283
# Computing HR contact map 284
# Computing HR contact map 285
# Computing HR contact map 286
# Computing HR contact map 287
# Computing HR contact map 288
# Computing HR contact map 289
# Computing HR contact map 290
# Computing HR contact map 291
# Computing HR contact map 292
# Computing HR contact map 293
# Computing HR contact map 294
# Computing HR contact map 295
# Computing HR contact map 296
# Computing HR contact map 297
# Computing HR contact map 298
# Computing HR contact map 299
# Computing HR contact map 300
# Computing HR contact map 301
# Computing HR contact map 302
# Computing HR contact map 303
# Computing HR contact map 304
# Computing HR contact map 305
# Computing HR contact map 306
# Computing HR contact map 307
# Computing HR contact map 308
# Computing HR contact map 309
# Computing HR contact map 310
# Computing HR contact map 311
# Computing HR contact map 312
# Computing HR contact map 313
# Computing HR contact map 314
# Computing HR contact map 315
# Computing HR contact map 316
# Computing HR contact map 317
# Computing HR contact map 318
# Computing HR contact map 319
# Computing HR contact map 320
# Computing HR contact map 321
# Computing HR contact map 322
# Computing HR contact map 323
# Computing HR contact map 324
# Computing HR contact map 325
# Computing HR contact map 326
# Computing HR contact map 327
# Computing HR contact map 328
# Computing HR contact map 329
# Computing HR contact map 330
# Computing HR contact map 331
# Computing HR contact map 332
# Computing HR contact map 333
# Computing HR contact map 334
# Computing HR contact map 335
# Computing HR contact map 336
# Computing HR contact map 337
# Computing HR contact map 338
# Computing HR contact map 339
# Computing HR contact map 340
# Computing HR contact map 341
# Computing HR contact map 342
# Computing HR contact map 343
# Computing HR contact map 344
# Computing HR contact map 345
# Computing HR contact map 346
# Computing HR contact map 347
# Computing HR contact map 348
# Computing HR contact map 349
# Computing HR contact map 350
# Computing HR contact map 351
# Computing HR contact map 352
# Computing HR contact map 353
# Computing HR contact map 354
# Computing HR contact map 355
# Computing HR contact map 356
# Computing HR contact map 357
# Computing HR contact map 358
# Computing HR contact map 359
# Computing HR contact map 360
# Computing HR contact map 361
# Computing HR contact map 362
# Computing HR contact map 363
# Computing HR contact map 364
# Computing HR contact map 365
# Computing HR contact map 366
# Computing HR contact map 367
# Computing HR contact map 368
# Computing HR contact map 369
# Computing HR contact map 370
# Computing HR contact map 371
# Computing HR contact map 372
# Computing HR contact map 373
# Computing HR contact map 374
# Computing HR contact map 375
# Computing HR contact map 376
# Computing HR contact map 377
# Computing HR contact map 378
# Computing HR contact map 379
# Computing HR contact map 380
# Computing HR contact map 381
# Computing HR contact map 382
# Computing HR contact map 383
# Computing HR contact map 384
# Computing HR contact map 385
# Computing HR contact map 386
# Computing HR contact map 387
# Computing HR contact map 388
# Computing HR contact map 389
# Computing HR contact map 390
# Computing HR contact map 391
# Computing HR contact map 392
# Computing HR contact map 393
# Computing HR contact map 394
# Computing HR contact map 395
# Computing HR contact map 396
# Computing HR contact map 397
# Computing HR contact map 398
# Computing HR contact map 399
# Computing HR contact map 400
# Computing HR contact map 401
# Computing HR contact map 402
# Computing HR contact map 403
# Computing HR contact map 404
# Computing HR contact map 405
# Computing HR contact map 406
# Computing HR contact map 407
# Computing HR contact map 408
# Computing HR contact map 409
# Computing HR contact map 410
# Computing HR contact map 411
# Computing HR contact map 412
# Computing HR contact map 413
# Computing HR contact map 414
# Computing HR contact map 415
# Computing HR contact map 416
# Computing HR contact map 417
# Computing HR contact map 418
# Computing HR contact map 419
# Computing HR contact map 420
# Computing HR contact map 421
# Computing HR contact map 422
# Computing HR contact map 423
# Computing HR contact map 424
# Computing HR contact map 425
# Computing HR contact map 426
# Computing HR contact map 427
# Computing HR contact map 428
# Computing HR contact map 429
# Computing HR contact map 430
# Computing HR contact map 431
# Computing HR contact map 432
# Computing HR contact map 433
# Computing HR contact map 434
# Computing HR contact map 435
# Computing HR contact map 436
# Computing HR contact map 437
# Computing HR contact map 438
# Computing HR contact map 439
# Computing HR contact map 440
# Computing HR contact map 441
# Computing HR contact map 442
# Computing HR contact map 443
# Computing HR contact map 444
# Computing HR contact map 445
# Computing HR contact map 446
# Computing HR contact map 447
# Computing HR contact map 448
# Computing HR contact map 449
# Computing HR contact map 450
# Computing HR contact map 451
# Computing HR contact map 452
# Computing HR contact map 453
# Computing HR contact map 454
# Computing HR contact map 455
# Computing HR contact map 456
# Computing HR contact map 457
# Computing HR contact map 458
# Computing HR contact map 459
# Computing HR contact map 460
# Computing HR contact map 461
# Computing HR contact map 462
# Computing HR contact map 463
# Computing HR contact map 464
# Computing HR contact map 465
# Computing HR contact map 466
# Computing HR contact map 467
# Computing HR contact map 468
# Computing HR contact map 469
# Computing HR contact map 470
# Computing HR contact map 471
# Computing HR contact map 472
# Computing HR contact map 473
# Computing HR contact map 474
# Computing HR contact map 475
# Computing HR contact map 476
# Computing HR contact map 477
# Computing HR contact map 478
# Computing HR contact map 479
# Computing HR contact map 480
# Computing HR contact map 481
# Computing HR contact map 482
# Computing HR contact map 483
# Computing HR contact map 484
# Computing HR contact map 485
# Computing HR contact map 486
# Computing HR contact map 487
# Computing HR contact map 488
# Computing HR contact map 489
# Computing HR contact map 490
# Computing HR contact map 491
# Computing HR contact map 492
# Computing HR contact map 493
# Computing HR contact map 494
# Computing HR contact map 495
# Computing HR contact map 496
# Computing HR contact map 497
# Computing HR contact map 498
# Computing HR contact map 499
# Computing HR contact map 500
# Computing HR contact map 501
# Computing HR contact map 502
# Computing HR contact map 503
# Computing HR contact map 504
# Computing HR contact map 505
# Computing HR contact map 506
# Computing HR contact map 507
# Computing HR contact map 508
# Computing HR contact map 509
# Computing HR contact map 510
# Computing HR contact map 511
# Computing HR contact map 512
# Computing HR contact map 513
# Computing HR contact map 514
# Computing HR contact map 515
# Computing HR contact map 516
# Computing HR contact map 517
# Computing HR contact map 518
# Computing HR contact map 519
# Computing HR contact map 520
# Computing HR contact map 521
# Computing HR contact map 522
# Computing HR contact map 523
# Computing HR contact map 524
# Computing HR contact map 525
# Computing HR contact map 526
# Computing HR contact map 527
# Computing HR contact map 528
# Computing HR contact map 529
# Computing HR contact map 530
# Computing HR contact map 531
# Computing HR contact map 532
# Computing HR contact map 533
# Computing HR contact map 534
# Computing HR contact map 535
# Computing HR contact map 536
# Computing HR contact map 537
# Computing HR contact map 538
# Computing HR contact map 539
# Computing HR contact map 540
# Computing HR contact map 541
# Computing HR contact map 542
# Computing HR contact map 543
# Computing HR contact map 544
# Computing HR contact map 545
# Computing HR contact map 546
# Computing HR contact map 547
# Computing HR contact map 548
# Computing HR contact map 549
# Computing HR contact map 550
# Computing HR contact map 551
# Computing HR contact map 552
# Computing HR contact map 553
# Computing HR contact map 554
# Computing HR contact map 555
# Computing HR contact map 556
# Computing HR contact map 557
# Computing HR contact map 558
# Computing HR contact map 559
# Computing HR contact map 560
# Computing HR contact map 561
# Computing HR contact map 562
# Computing HR contact map 563
# Computing HR contact map 564
# Computing HR contact map 565
# Computing HR contact map 566
# Computing HR contact map 567
# Computing HR contact map 568
# Computing HR contact map 569
# Computing HR contact map 570
# Computing HR contact map 571
# Computing HR contact map 572
# Computing HR contact map 573
# Computing HR contact map 574
# Computing HR contact map 575
# Computing HR contact map 576
# Computing HR contact map 577
# Computing HR contact map 578
# Computing HR contact map 579
# Computing HR contact map 580
# Computing HR contact map 581
# Computing HR contact map 582
# Computing HR contact map 583
# Computing HR contact map 584
# Computing HR contact map 585
# Computing HR contact map 586
# Computing HR contact map 587
# Computing HR contact map 588
# Computing HR contact map 589
# Computing HR contact map 590
# Computing HR contact map 591
# Computing HR contact map 592
# Computing HR contact map 593
# Computing HR contact map 594
# Computing HR contact map 595
# Computing HR contact map 596
# Computing HR contact map 597
# Computing HR contact map 598
# Computing HR contact map 599
# Computing HR contact map 600
# Computing HR contact map 601
# Computing HR contact map 602
# Computing HR contact map 603
# Computing HR contact map 604
# Computing HR contact map 605
# Computing HR contact map 606
# Computing HR contact map 607
# Computing HR contact map 608
# Computing HR contact map 609
# Computing HR contact map 610
# Computing HR contact map 611
# Computing HR contact map 612
# Computing HR contact map 613
# Computing HR contact map 614
# Computing HR contact map 615
# Computing HR contact map 616
# Computing HR contact map 617
# Computing HR contact map 618
# Computing HR contact map 619
# Computing HR contact map 620
# Computing HR contact map 621
# Computing HR contact map 622
# Computing HR contact map 623
# Computing HR contact map 624
# Computing HR contact map 625
# Computing HR contact map 626
# Computing HR contact map 627
# Computing HR contact map 628
# Computing HR contact map 629
# Computing HR contact map 630
# Computing HR contact map 631
# Computing HR contact map 632
# Computing HR contact map 633
# Computing HR contact map 634
# Computing HR contact map 635
# Computing HR contact map 636
# Computing HR contact map 637
# Computing HR contact map 638
# Computing HR contact map 639
# Computing HR contact map 640
# Computing HR contact map 641
# Computing HR contact map 642
# Computing HR contact map 643
# Computing HR contact map 644
# Computing HR contact map 645
# Computing HR contact map 646
# Computing HR contact map 647
# Computing HR contact map 648
# Computing HR contact map 649
# Computing HR contact map 650
# Computing HR contact map 651
# Computing HR contact map 652
# Computing HR contact map 653
# Computing HR contact map 654
# Computing HR contact map 655
# Computing HR contact map 656
# Computing HR contact map 657
# Computing HR contact map 658
# Computing HR contact map 659
# Computing HR contact map 660
# Computing HR contact map 661
# Computing HR contact map 662
# Computing HR contact map 663
# Computing HR contact map 664
# Computing HR contact map 665
# Computing HR contact map 666
# Computing HR contact map 667
# Computing HR contact map 668
# Computing HR contact map 669
# Computing HR contact map 670
# Computing HR contact map 671
# Computing HR contact map 672
# Computing HR contact map 673
# Computing HR contact map 674
# Computing HR contact map 675
# Computing HR contact map 676
# Computing HR contact map 677
# Computing HR contact map 678
# Computing HR contact map 679
# Computing HR contact map 680
# Computing HR contact map 681
# Computing HR contact map 682
# Computing HR contact map 683
# Computing HR contact map 684
# Computing HR contact map 685
# Computing HR contact map 686
# Computing HR contact map 687
# Computing HR contact map 688
# Computing HR contact map 689
# Computing HR contact map 690
# Computing HR contact map 691
# Computing HR contact map 692
# Computing HR contact map 693
# Computing HR contact map 694
# Computing HR contact map 695
# Computing HR contact map 696
# Computing HR contact map 697
# Computing HR contact map 698
# Computing HR contact map 699
# Computing HR contact map 700
# Computing HR contact map 701
# Computing HR contact map 702
# Computing HR contact map 703
# Computing HR contact map 704
# Computing HR contact map 705
# Computing HR contact map 706
# Computing HR contact map 707
# Computing HR contact map 708
# Computing HR contact map 709
# Computing HR contact map 710
# Computing HR contact map 711
# Computing HR contact map 712
# Computing HR contact map 713
# Computing HR contact map 714
# Computing HR contact map 715
# Computing HR contact map 716
# Computing HR contact map 717
# Computing HR contact map 718
# Computing HR contact map 719
# Computing HR contact map 720
# Computing HR contact map 721
# Computing HR contact map 722
# Computing HR contact map 723
# Computing HR contact map 724
# Computing HR contact map 725
# Computing HR contact map 726
# Computing HR contact map 727
# Computing HR contact map 728
# Computing HR contact map 729
# Computing HR contact map 730
# Computing HR contact map 731
# Computing HR contact map 732
# Computing HR contact map 733
# Computing HR contact map 734
# Computing HR contact map 735
# Computing HR contact map 736
# Computing HR contact map 737
# Computing HR contact map 738
# Computing HR contact map 739
# Computing HR contact map 740
# Computing HR contact map 741
# Computing HR contact map 742
# Computing HR contact map 743
# Computing HR contact map 744
# Computing HR contact map 745
# Computing HR contact map 746
# Computing HR contact map 747
# Computing HR contact map 748
# Computing HR contact map 749
# Computing HR contact map 750
# Computing HR contact map 751
# Computing HR contact map 752
# Computing HR contact map 753
# Computing HR contact map 754
# Computing HR contact map 755
# Computing HR contact map 756
# Computing HR contact map 757
# Computing HR contact map 758
# Computing HR contact map 759
# Computing HR contact map 760
# Computing HR contact map 761
# Computing HR contact map 762
# Computing HR contact map 763
# Computing HR contact map 764
# Computing HR contact map 765
# Computing HR contact map 766
# Computing HR contact map 767
# Computing HR contact map 768
# Computing HR contact map 769
# Computing HR contact map 770
# Computing HR contact map 771
# Computing HR contact map 772
# Computing HR contact map 773
# Computing HR contact map 774
# Computing HR contact map 775
# Computing HR contact map 776
# Computing HR contact map 777
# Computing HR contact map 778
# Computing HR contact map 779
# Computing HR contact map 780
# Computing HR contact map 781
# Computing HR contact map 782
# Computing HR contact map 783
# Computing HR contact map 784
# Computing HR contact map 785
# Computing HR contact map 786
# Computing HR contact map 787
# Computing HR contact map 788
# Computing HR contact map 789
# Computing HR contact map 790
# Computing HR contact map 791
# Computing HR contact map 792
# Computing HR contact map 793
# Computing HR contact map 794
# Computing HR contact map 795
# Computing HR contact map 796
# Computing HR contact map 797
# Computing HR contact map 798
# Computing HR contact map 799
# Computing HR contact map 800
# Computing HR contact map 801
# Computing HR contact map 802
# Computing HR contact map 803
# Computing HR contact map 804
# Computing HR contact map 805
# Computing HR contact map 806
# Computing HR contact map 807
# Computing HR contact map 808
# Computing HR contact map 809
# Computing HR contact map 810
# Computing HR contact map 811
# Computing HR contact map 812
# Computing HR contact map 813
# Computing HR contact map 814
# Computing HR contact map 815
# Computing HR contact map 816
# Computing HR contact map 817
# Computing HR contact map 818
# Computing HR contact map 819
# Computing HR contact map 820
# Computing HR contact map 821
# Computing HR contact map 822
# Computing HR contact map 823
# Computing HR contact map 824
# Computing HR contact map 825
# Computing HR contact map 826
# Computing HR contact map 827
# Computing HR contact map 828
# Computing HR contact map 829
# Computing HR contact map 830
# Computing HR contact map 831
# Computing HR contact map 832
# Computing HR contact map 833
# Computing HR contact map 834
# Computing HR contact map 835
# Computing HR contact map 836
# Computing HR contact map 837
# Computing HR contact map 838
# Computing HR contact map 839
# Computing HR contact map 840
# Computing HR contact map 841
# Computing HR contact map 842
# Computing HR contact map 843
# Computing HR contact map 844
# Computing HR contact map 845
# Computing HR contact map 846
# Computing HR contact map 847
# Computing HR contact map 848
# Computing HR contact map 849
# Computing HR contact map 850
# Computing HR contact map 851
# Computing HR contact map 852
# Computing HR contact map 853
# Computing HR contact map 854
# Computing HR contact map 855
# Computing HR contact map 856
# Computing HR contact map 857
# Computing HR contact map 858
# Computing HR contact map 859
# Computing HR contact map 860
# Computing HR contact map 861
# Computing HR contact map 862
# Computing HR contact map 863
# Computing HR contact map 864
# Computing HR contact map 865
# Computing HR contact map 866
# Computing HR contact map 867
# Computing HR contact map 868
# Computing HR contact map 869
# Computing HR contact map 870
# Computing HR contact map 871
# Computing HR contact map 872
# Computing HR contact map 873
# Computing HR contact map 874
# Computing HR contact map 875
# Computing HR contact map 876
# Computing HR contact map 877
# Computing HR contact map 878
# Computing HR contact map 879
# Computing HR contact map 880
# Computing HR contact map 881
# Computing HR contact map 882
# Computing HR contact map 883
# Computing HR contact map 884
# Computing HR contact map 885
# Computing HR contact map 886
# Computing HR contact map 887
# Computing HR contact map 888
# Computing HR contact map 889
# Computing HR contact map 890
# Computing HR contact map 891
# Computing HR contact map 892
# Computing HR contact map 893
# Computing HR contact map 894
# Computing HR contact map 895
# Computing HR contact map 896
# Computing HR contact map 897
# Computing HR contact map 898
# Computing HR contact map 899
# Computing HR contact map 900
# Computing HR contact map 901
# Computing HR contact map 902
# Computing HR contact map 903
# Computing HR contact map 904
# Computing HR contact map 905
# Computing HR contact map 906
# Computing HR contact map 907
# Computing HR contact map 908
# Computing HR contact map 909
# Computing HR contact map 910
# Computing HR contact map 911
# Computing HR contact map 912
# Computing HR contact map 913
# Computing HR contact map 914
# Computing HR contact map 915
# Computing HR contact map 916
# Computing HR contact map 917
# Computing HR contact map 918
# Computing HR contact map 919
# Computing HR contact map 920
# Computing HR contact map 921
# Computing HR contact map 922
# Computing HR contact map 923
# Computing HR contact map 924
# Computing HR contact map 925
# Computing HR contact map 926
# Computing HR contact map 927
# Computing HR contact map 928
# Computing HR contact map 929
# Computing HR contact map 930
# Computing HR contact map 931
# Computing HR contact map 932
# Computing HR contact map 933
# Computing HR contact map 934
# Computing HR contact map 935
# Computing HR contact map 936
# Computing HR contact map 937
# Computing HR contact map 938
# Computing HR contact map 939
# Computing HR contact map 940
# Computing HR contact map 941
# Computing HR contact map 942
# Computing HR contact map 943
# Computing HR contact map 944
# Computing HR contact map 945
# Computing HR contact map 946
# Computing HR contact map 947
# Computing HR contact map 948
# Computing HR contact map 949
# Computing HR contact map 950
# Computing HR contact map 951
# Computing HR contact map 952
# Computing HR contact map 953
# Computing HR contact map 954
# Computing HR contact map 955
# Computing HR contact map 956
# Computing HR contact map 957
# Computing HR contact map 958
# Computing HR contact map 959
# Computing HR contact map 960
# Computing HR contact map 961
# Computing HR contact map 962
# Computing HR contact map 963
# Computing HR contact map 964
# Computing HR contact map 965
# Computing HR contact map 966
# Computing HR contact map 967
# Computing HR contact map 968
# Computing HR contact map 969
# Computing HR contact map 970
# Computing HR contact map 971
# Computing HR contact map 972
# Computing HR contact map 973
# Computing HR contact map 974
# Computing HR contact map 975
# Computing HR contact map 976
# Computing HR contact map 977
# Computing HR contact map 978
# Computing HR contact map 979
# Computing HR contact map 980
# Computing HR contact map 981
# Computing HR contact map 982
# Computing HR contact map 983
# Computing HR contact map 984
# Computing HR contact map 985
# Computing HR contact map 986
# Computing HR contact map 987
# Computing HR contact map 988
# Computing HR contact map 989
# Computing HR contact map 990
# Computing HR contact map 991
# Computing HR contact map 992
# Computing HR contact map 993
# Computing HR contact map 994
# Computing HR contact map 995
# Computing HR contact map 996
# Computing HR contact map 997
# Computing HR contact map 998
# Computing HR contact map 999
# Computing HR contact map 1000
# All distance maps retrieved
# Computing global LR contact map
# 50 1225 200
# Generating 3D ensambles with downsampled chains: 1000
# Submitted batch job 41592234
# Downsampling: 2500 chains
# Computing HR contact map 1
# Computing HR contact map 2
# Computing HR contact map 3
# Computing HR contact map 4
# Computing HR contact map 5
# Computing HR contact map 6
# Computing HR contact map 7
# Computing HR contact map 8
# Computing HR contact map 9
# Computing HR contact map 10
# Computing HR contact map 11
# Computing HR contact map 12
# Computing HR contact map 13
# Computing HR contact map 14
# Computing HR contact map 15
# Computing HR contact map 16
# Computing HR contact map 17
# Computing HR contact map 18
# Computing HR contact map 19
# Computing HR contact map 20
# Computing HR contact map 21
# Computing HR contact map 22
# Computing HR contact map 23
# Computing HR contact map 24
# Computing HR contact map 25
# Computing HR contact map 26
# Computing HR contact map 27
# Computing HR contact map 28
# Computing HR contact map 29
# Computing HR contact map 30
# Computing HR contact map 31
# Computing HR contact map 32
# Computing HR contact map 33
# Computing HR contact map 34
# Computing HR contact map 35
# Computing HR contact map 36
# Computing HR contact map 37
# Computing HR contact map 38
# Computing HR contact map 39
# Computing HR contact map 40
# Computing HR contact map 41
# Computing HR contact map 42
# Computing HR contact map 43
# Computing HR contact map 44
# Computing HR contact map 45
# Computing HR contact map 46
# Computing HR contact map 47
# Computing HR contact map 48
# Computing HR contact map 49
# Computing HR contact map 50
# Computing HR contact map 51
# Computing HR contact map 52
# Computing HR contact map 53
# Computing HR contact map 54
# Computing HR contact map 55
# Computing HR contact map 56
# Computing HR contact map 57
# Computing HR contact map 58
# Computing HR contact map 59
# Computing HR contact map 60
# Computing HR contact map 61
# Computing HR contact map 62
# Computing HR contact map 63
# Computing HR contact map 64
# Computing HR contact map 65
# Computing HR contact map 66
# Computing HR contact map 67
# Computing HR contact map 68
# Computing HR contact map 69
# Computing HR contact map 70
# Computing HR contact map 71
# Computing HR contact map 72
# Computing HR contact map 73
# Computing HR contact map 74
# Computing HR contact map 75
# Computing HR contact map 76
# Computing HR contact map 77
# Computing HR contact map 78
# Computing HR contact map 79
# Computing HR contact map 80
# Computing HR contact map 81
# Computing HR contact map 82
# Computing HR contact map 83
# Computing HR contact map 84
# Computing HR contact map 85
# Computing HR contact map 86
# Computing HR contact map 87
# Computing HR contact map 88
# Computing HR contact map 89
# Computing HR contact map 90
# Computing HR contact map 91
# Computing HR contact map 92
# Computing HR contact map 93
# Computing HR contact map 94
# Computing HR contact map 95
# Computing HR contact map 96
# Computing HR contact map 97
# Computing HR contact map 98
# Computing HR contact map 99
# Computing HR contact map 100
# Computing HR contact map 101
# Computing HR contact map 102
# Computing HR contact map 103
# Computing HR contact map 104
# Computing HR contact map 105
# Computing HR contact map 106
# Computing HR contact map 107
# Computing HR contact map 108
# Computing HR contact map 109
# Computing HR contact map 110
# Computing HR contact map 111
# Computing HR contact map 112
# Computing HR contact map 113
# Computing HR contact map 114
# Computing HR contact map 115
# Computing HR contact map 116
# Computing HR contact map 117
# Computing HR contact map 118
# Computing HR contact map 119
# Computing HR contact map 120
# Computing HR contact map 121
# Computing HR contact map 122
# Computing HR contact map 123
# Computing HR contact map 124
# Computing HR contact map 125
# Computing HR contact map 126
# Computing HR contact map 127
# Computing HR contact map 128
# Computing HR contact map 129
# Computing HR contact map 130
# Computing HR contact map 131
# Computing HR contact map 132
# Computing HR contact map 133
# Computing HR contact map 134
# Computing HR contact map 135
# Computing HR contact map 136
# Computing HR contact map 137
# Computing HR contact map 138
# Computing HR contact map 139
# Computing HR contact map 140
# Computing HR contact map 141
# Computing HR contact map 142
# Computing HR contact map 143
# Computing HR contact map 144
# Computing HR contact map 145
# Computing HR contact map 146
# Computing HR contact map 147
# Computing HR contact map 148
# Computing HR contact map 149
# Computing HR contact map 150
# Computing HR contact map 151
# Computing HR contact map 152
# Computing HR contact map 153
# Computing HR contact map 154
# Computing HR contact map 155
# Computing HR contact map 156
# Computing HR contact map 157
# Computing HR contact map 158
# Computing HR contact map 159
# Computing HR contact map 160
# Computing HR contact map 161
# Computing HR contact map 162
# Computing HR contact map 163
# Computing HR contact map 164
# Computing HR contact map 165
# Computing HR contact map 166
# Computing HR contact map 167
# Computing HR contact map 168
# Computing HR contact map 169
# Computing HR contact map 170
# Computing HR contact map 171
# Computing HR contact map 172
# Computing HR contact map 173
# Computing HR contact map 174
# Computing HR contact map 175
# Computing HR contact map 176
# Computing HR contact map 177
# Computing HR contact map 178
# Computing HR contact map 179
# Computing HR contact map 180
# Computing HR contact map 181
# Computing HR contact map 182
# Computing HR contact map 183
# Computing HR contact map 184
# Computing HR contact map 185
# Computing HR contact map 186
# Computing HR contact map 187
# Computing HR contact map 188
# Computing HR contact map 189
# Computing HR contact map 190
# Computing HR contact map 191
# Computing HR contact map 192
# Computing HR contact map 193
# Computing HR contact map 194
# Computing HR contact map 195
# Computing HR contact map 196
# Computing HR contact map 197
# Computing HR contact map 198
# Computing HR contact map 199
# Computing HR contact map 200
# Computing HR contact map 201
# Computing HR contact map 202
# Computing HR contact map 203
# Computing HR contact map 204
# Computing HR contact map 205
# Computing HR contact map 206
# Computing HR contact map 207
# Computing HR contact map 208
# Computing HR contact map 209
# Computing HR contact map 210
# Computing HR contact map 211
# Computing HR contact map 212
# Computing HR contact map 213
# Computing HR contact map 214
# Computing HR contact map 215
# Computing HR contact map 216
# Computing HR contact map 217
# Computing HR contact map 218
# Computing HR contact map 219
# Computing HR contact map 220
# Computing HR contact map 221
# Computing HR contact map 222
# Computing HR contact map 223
# Computing HR contact map 224
# Computing HR contact map 225
# Computing HR contact map 226
# Computing HR contact map 227
# Computing HR contact map 228
# Computing HR contact map 229
# Computing HR contact map 230
# Computing HR contact map 231
# Computing HR contact map 232
# Computing HR contact map 233
# Computing HR contact map 234
# Computing HR contact map 235
# Computing HR contact map 236
# Computing HR contact map 237
# Computing HR contact map 238
# Computing HR contact map 239
# Computing HR contact map 240
# Computing HR contact map 241
# Computing HR contact map 242
# Computing HR contact map 243
# Computing HR contact map 244
# Computing HR contact map 245
# Computing HR contact map 246
# Computing HR contact map 247
# Computing HR contact map 248
# Computing HR contact map 249
# Computing HR contact map 250
# Computing HR contact map 251
# Computing HR contact map 252
# Computing HR contact map 253
# Computing HR contact map 254
# Computing HR contact map 255
# Computing HR contact map 256
# Computing HR contact map 257
# Computing HR contact map 258
# Computing HR contact map 259
# Computing HR contact map 260
# Computing HR contact map 261
# Computing HR contact map 262
# Computing HR contact map 263
# Computing HR contact map 264
# Computing HR contact map 265
# Computing HR contact map 266
# Computing HR contact map 267
# Computing HR contact map 268
# Computing HR contact map 269
# Computing HR contact map 270
# Computing HR contact map 271
# Computing HR contact map 272
# Computing HR contact map 273
# Computing HR contact map 274
# Computing HR contact map 275
# Computing HR contact map 276
# Computing HR contact map 277
# Computing HR contact map 278
# Computing HR contact map 279
# Computing HR contact map 280
# Computing HR contact map 281
# Computing HR contact map 282
# Computing HR contact map 283
# Computing HR contact map 284
# Computing HR contact map 285
# Computing HR contact map 286
# Computing HR contact map 287
# Computing HR contact map 288
# Computing HR contact map 289
# Computing HR contact map 290
# Computing HR contact map 291
# Computing HR contact map 292
# Computing HR contact map 293
# Computing HR contact map 294
# Computing HR contact map 295
# Computing HR contact map 296
# Computing HR contact map 297
# Computing HR contact map 298
# Computing HR contact map 299
# Computing HR contact map 300
# ...
# Computing HR contact map 3223
# Computing HR contact map 3224
# Computing HR contact map 3225
# Computing HR contact map 3226
# Computing HR contact map 3227
# Computing HR contact map 3228
# Computing HR contact map 3229
# Computing HR contact map 3230
# Computing HR contact map 3231
# Computing HR contact map 3232
# Computing HR contact map 3233
# Computing HR contact map 3234
# Computing HR contact map 3235
# Computing HR contact map 3236
# Computing HR contact map 3237
# Computing HR contact map 3238
# Computing HR contact map 3239
# Computing HR contact map 3240
# Computing HR contact map 3241
# Computing HR contact map 3242
# Computing HR contact map 3243
# Computing HR contact map 3244
# Computing HR contact map 3245
# Computing HR contact map 3246
# Computing HR contact map 3247
# Computing HR contact map 3248
# Computing HR contact map 3249
# Computing HR contact map 3250
# Computing HR contact map 3251
# Computing HR contact map 3252
# Computing HR contact map 3253
# Computing HR contact map 3254
# Computing HR contact map 3255
# Computing HR contact map 3256
# Computing HR contact map 3257
# Computing HR contact map 3258
# Computing HR contact map 3259
# Computing HR contact map 3260
# Computing HR contact map 3261
# Computing HR contact map 3262
# Computing HR contact map 3263
# Computing HR contact map 3264
# Computing HR contact map 3265
# Computing HR contact map 3266
# Computing HR contact map 3267
# Computing HR contact map 3268
# Computing HR contact map 3269
# Computing HR contact map 3270
# Computing HR contact map 3271
# Computing HR contact map 3272
# Computing HR contact map 3273
# Computing HR contact map 3274
# Computing HR contact map 3275
# Computing HR contact map 3276
# Computing HR contact map 3277
# Computing HR contact map 3278
# Computing HR contact map 3279
# Computing HR contact map 3280
# Computing HR contact map 3281
# Computing HR contact map 3282
# Computing HR contact map 3283
# Computing HR contact map 3284
# Computing HR contact map 3285
# Computing HR contact map 3286
# Computing HR contact map 3287
# Computing HR contact map 3288
# Computing HR contact map 3289
# Computing HR contact map 3290
# Computing HR contact map 3291
# Computing HR contact map 3292
# Computing HR contact map 3293
# Computing HR contact map 3294
# Computing HR contact map 3295
# Computing HR contact map 3296
# Computing HR contact map 3297
# Computing HR contact map 3298
# Computing HR contact map 3299
# Computing HR contact map 3300
# Computing HR contact map 3301
# Computing HR contact map 3302
# Computing HR contact map 3303
# Computing HR contact map 3304
# Computing HR contact map 3305
# Computing HR contact map 3306
# Computing HR contact map 3307
# Computing HR contact map 3308
# Computing HR contact map 3309
# Computing HR contact map 3310
# Computing HR contact map 3311
# Computing HR contact map 3312
# Computing HR contact map 3313
# Computing HR contact map 3314
# Computing HR contact map 3315
# Computing HR contact map 3316
# Computing HR contact map 3317
# Computing HR contact map 3318
# Computing HR contact map 3319
# Computing HR contact map 3320
# Computing HR contact map 3321
# Computing HR contact map 3322
# Computing HR contact map 3323
# Computing HR contact map 3324
# Computing HR contact map 3325
# Computing HR contact map 3326
# Computing HR contact map 3327
# Computing HR contact map 3328
# Computing HR contact map 3329
# Computing HR contact map 3330
# Computing HR contact map 3331
# Computing HR contact map 3332
# Computing HR contact map 3333
# Computing HR contact map 3334
# Computing HR contact map 3335
# Computing HR contact map 3336
# Computing HR contact map 3337
# Computing HR contact map 3338
# Computing HR contact map 3339
# Computing HR contact map 3340
# Computing HR contact map 3341
# Computing HR contact map 3342
# Computing HR contact map 3343
# Computing HR contact map 3344
# Computing HR contact map 3345
# Computing HR contact map 3346
# Computing HR contact map 3347
# Computing HR contact map 3348
# Computing HR contact map 3349
# Computing HR contact map 3350
# Computing HR contact map 3351
# Computing HR contact map 3352
# Computing HR contact map 3353
# Computing HR contact map 3354
# Computing HR contact map 3355
# Computing HR contact map 3356
# Computing HR contact map 3357
# Computing HR contact map 3358
# Computing HR contact map 3359
# Computing HR contact map 3360
# Computing HR contact map 3361
# Computing HR contact map 3362
# Computing HR contact map 3363
# Computing HR contact map 3364
# Computing HR contact map 3365
# Computing HR contact map 3366
# Computing HR contact map 3367
# Computing HR contact map 3368
# Computing HR contact map 3369
# Computing HR contact map 3370
# Computing HR contact map 3371
# Computing HR contact map 3372
# Computing HR contact map 3373
# Computing HR contact map 3374
# Computing HR contact map 3375
# Computing HR contact map 3376
# Computing HR contact map 3377
# Computing HR contact map 3378
# Computing HR contact map 3379
# Computing HR contact map 3380
# Computing HR contact map 3381
# Computing HR contact map 3382
# Computing HR contact map 3383
# Computing HR contact map 3384
# Computing HR contact map 3385
# Computing HR contact map 3386
# Computing HR contact map 3387
# Computing HR contact map 3388
# Computing HR contact map 3389
# Computing HR contact map 3390
# Computing HR contact map 3391
# Computing HR contact map 3392
# Computing HR contact map 3393
# Computing HR contact map 3394
# Computing HR contact map 3395
# Computing HR contact map 3396
# Computing HR contact map 3397
# Computing HR contact map 3398
# Computing HR contact map 3399
# Computing HR contact map 3400
# Computing HR contact map 3401
# Computing HR contact map 3402
# Computing HR contact map 3403
# Computing HR contact map 3404
# Computing HR contact map 3405
# Computing HR contact map 3406
# Computing HR contact map 3407
# Computing HR contact map 3408
# Computing HR contact map 3409
# Computing HR contact map 3410
# Computing HR contact map 3411
# Computing HR contact map 3412
# Computing HR contact map 3413
# Computing HR contact map 3414
# Computing HR contact map 3415
# Computing HR contact map 3416
# Computing HR contact map 3417
# Computing HR contact map 3418
# Computing HR contact map 3419
# Computing HR contact map 3420
# Computing HR contact map 3421
# Computing HR contact map 3422
# Computing HR contact map 3423
# Computing HR contact map 3424
# Computing HR contact map 3425
# Computing HR contact map 3426
# Computing HR contact map 3427
# Computing HR contact map 3428
# Computing HR contact map 3429
# Computing HR contact map 3430
# Computing HR contact map 3431
# Computing HR contact map 3432
# Computing HR contact map 3433
# Computing HR contact map 3434
# Computing HR contact map 3435
# Computing HR contact map 3436
# Computing HR contact map 3437
# Computing HR contact map 3438
# Computing HR contact map 3439
# Computing HR contact map 3440
# Computing HR contact map 3441
# Computing HR contact map 3442
# Computing HR contact map 3443
# Computing HR contact map 3444
# Computing HR contact map 3445
# Computing HR contact map 3446
# Computing HR contact map 3447
# Computing HR contact map 3448
# Computing HR contact map 3449
# Computing HR contact map 3450
# Computing HR contact map 3451
# Computing HR contact map 3452
# Computing HR contact map 3453
# Computing HR contact map 3454
# Computing HR contact map 3455
# Computing HR contact map 3456
# Computing HR contact map 3457
# Computing HR contact map 3458
# Computing HR contact map 3459
# Computing HR contact map 3460
# Computing HR contact map 3461
# Computing HR contact map 3462
# Computing HR contact map 3463
# Computing HR contact map 3464
# Computing HR contact map 3465
# Computing HR contact map 3466
# Computing HR contact map 3467
# Computing HR contact map 3468
# Computing HR contact map 3469
# Computing HR contact map 3470
# Computing HR contact map 3471
# Computing HR contact map 3472
# Computing HR contact map 3473
# Computing HR contact map 3474
# Computing HR contact map 3475
# Computing HR contact map 3476
# Computing HR contact map 3477
# Computing HR contact map 3478
# Computing HR contact map 3479
# Computing HR contact map 3480
# Computing HR contact map 3481
# Computing HR contact map 3482
# Computing HR contact map 3483
# Computing HR contact map 3484
# Computing HR contact map 3485
# Computing HR contact map 3486
# Computing HR contact map 3487
# Computing HR contact map 3488
# Computing HR contact map 3489
# Computing HR contact map 3490
# Computing HR contact map 3491
# Computing HR contact map 3492
# Computing HR contact map 3493
# Computing HR contact map 3494
# Computing HR contact map 3495
# Computing HR contact map 3496
# Computing HR contact map 3497
# Computing HR contact map 3498
# Computing HR contact map 3499
# Computing HR contact map 3500
# Computing HR contact map 3501
# Computing HR contact map 3502
# Computing HR contact map 3503
# Computing HR contact map 3504
# Computing HR contact map 3505
# Computing HR contact map 3506
# Computing HR contact map 3507
# Computing HR contact map 3508
# Computing HR contact map 3509
# Computing HR contact map 3510
# Computing HR contact map 3511
# Computing HR contact map 3512
# Computing HR contact map 3513
# Computing HR contact map 3514
# Computing HR contact map 3515
# Computing HR contact map 3516
# Computing HR contact map 3517
# Computing HR contact map 3518
# Computing HR contact map 3519
# Computing HR contact map 3520
# Computing HR contact map 3521
# Computing HR contact map 3522
# Computing HR contact map 3523
# Computing HR contact map 3524
# Computing HR contact map 3525
# Computing HR contact map 3526
# Computing HR contact map 3527
# Computing HR contact map 3528
# Computing HR contact map 3529
# Computing HR contact map 3530
# Computing HR contact map 3531
# Computing HR contact map 3532
# Computing HR contact map 3533
# Computing HR contact map 3534
# Computing HR contact map 3535
# Computing HR contact map 3536
# Computing HR contact map 3537
# Computing HR contact map 3538
# Computing HR contact map 3539
# Computing HR contact map 3540
# Computing HR contact map 3541
# Computing HR contact map 3542
# Computing HR contact map 3543
# Computing HR contact map 3544
# Computing HR contact map 3545
# Computing HR contact map 3546
# Computing HR contact map 3547
# Computing HR contact map 3548
# Computing HR contact map 3549
# Computing HR contact map 3550
# Computing HR contact map 3551
# Computing HR contact map 3552
# Computing HR contact map 3553
# Computing HR contact map 3554
# Computing HR contact map 3555
# Computing HR contact map 3556
# Computing HR contact map 3557
# Computing HR contact map 3558
# Computing HR contact map 3559
# Computing HR contact map 3560
# Computing HR contact map 3561
# Computing HR contact map 3562
# Computing HR contact map 3563
# Computing HR contact map 3564
# Computing HR contact map 3565
# Computing HR contact map 3566
# Computing HR contact map 3567
# Computing HR contact map 3568
# Computing HR contact map 3569
# Computing HR contact map 3570
# Computing HR contact map 3571
# Computing HR contact map 3572
# Computing HR contact map 3573
# Computing HR contact map 3574
# Computing HR contact map 3575
# Computing HR contact map 3576
# Computing HR contact map 3577
# Computing HR contact map 3578
# Computing HR contact map 3579
# Computing HR contact map 3580
# Computing HR contact map 3581
# Computing HR contact map 3582
# Computing HR contact map 3583
# Computing HR contact map 3584
# Computing HR contact map 3585
# Computing HR contact map 3586
# Computing HR contact map 3587
# Computing HR contact map 3588
# Computing HR contact map 3589
# Computing HR contact map 3590
# Computing HR contact map 3591
# Computing HR contact map 3592
# Computing HR contact map 3593
# Computing HR contact map 3594
# Computing HR contact map 3595
# Computing HR contact map 3596
# Computing HR contact map 3597
# Computing HR contact map 3598
# Computing HR contact map 3599
# Computing HR contact map 3600
# Computing HR contact map 3601
# Computing HR contact map 3602
# Computing HR contact map 3603
# Computing HR contact map 3604
# Computing HR contact map 3605
# Computing HR contact map 3606
# Computing HR contact map 3607
# Computing HR contact map 3608
# Computing HR contact map 3609
# Computing HR contact map 3610
# Computing HR contact map 3611
# Computing HR contact map 3612
# Computing HR contact map 3613
# Computing HR contact map 3614
# Computing HR contact map 3615
# Computing HR contact map 3616
# Computing HR contact map 3617
# Computing HR contact map 3618
# Computing HR contact map 3619
# Computing HR contact map 3620
# Computing HR contact map 3621
# Computing HR contact map 3622
# Computing HR contact map 3623
# Computing HR contact map 3624
# Computing HR contact map 3625
# Computing HR contact map 3626
# Computing HR contact map 3627
# Computing HR contact map 3628
# Computing HR contact map 3629
# Computing HR contact map 3630
# Computing HR contact map 3631
# Computing HR contact map 3632
# Computing HR contact map 3633
# Computing HR contact map 3634
# Computing HR contact map 3635
# Computing HR contact map 3636
# Computing HR contact map 3637
# Computing HR contact map 3638
# Computing HR contact map 3639
# Computing HR contact map 3640
# Computing HR contact map 3641
# Computing HR contact map 3642
# Computing HR contact map 3643
# Computing HR contact map 3644
# Computing HR contact map 3645
# Computing HR contact map 3646
# Computing HR contact map 3647
# Computing HR contact map 3648
# Computing HR contact map 3649
# Computing HR contact map 3650
# Computing HR contact map 3651
# Computing HR contact map 3652
# Computing HR contact map 3653
# Computing HR contact map 3654
# Computing HR contact map 3655
# Computing HR contact map 3656
# Computing HR contact map 3657
# Computing HR contact map 3658
# Computing HR contact map 3659
# Computing HR contact map 3660
# Computing HR contact map 3661
# Computing HR contact map 3662
# Computing HR contact map 3663
# Computing HR contact map 3664
# Computing HR contact map 3665
# Computing HR contact map 3666
# Computing HR contact map 3667
# Computing HR contact map 3668
# Computing HR contact map 3669
# Computing HR contact map 3670
# Computing HR contact map 3671
# Computing HR contact map 3672
# Computing HR contact map 3673
# Computing HR contact map 3674
# Computing HR contact map 3675
# Computing HR contact map 3676
# Computing HR contact map 3677
# Computing HR contact map 3678
# Computing HR contact map 3679
# Computing HR contact map 3680
# Computing HR contact map 3681
# Computing HR contact map 3682
# Computing HR contact map 3683
# Computing HR contact map 3684
# Computing HR contact map 3685
# Computing HR contact map 3686
# Computing HR contact map 3687
# Computing HR contact map 3688
# Computing HR contact map 3689
# Computing HR contact map 3690
# Computing HR contact map 3691
# Computing HR contact map 3692
# Computing HR contact map 3693
# Computing HR contact map 3694
# Computing HR contact map 3695
# Computing HR contact map 3696
# Computing HR contact map 3697
# Computing HR contact map 3698
# Computing HR contact map 3699
# Computing HR contact map 3700
# Computing HR contact map 3701
# Computing HR contact map 3702
# Computing HR contact map 3703
# Computing HR contact map 3704
# Computing HR contact map 3705
# Computing HR contact map 3706
# Computing HR contact map 3707
# Computing HR contact map 3708
# Computing HR contact map 3709
# Computing HR contact map 3710
# Computing HR contact map 3711
# Computing HR contact map 3712
# Computing HR contact map 3713
# Computing HR contact map 3714
# Computing HR contact map 3715
# Computing HR contact map 3716
# Computing HR contact map 3717
# Computing HR contact map 3718
# Computing HR contact map 3719
# Computing HR contact map 3720
# Computing HR contact map 3721
# Computing HR contact map 3722
# Computing HR contact map 3723
# Computing HR contact map 3724
# Computing HR contact map 3725
# Computing HR contact map 3726
# Computing HR contact map 3727
# Computing HR contact map 3728
# Computing HR contact map 3729
# Computing HR contact map 3730
# Computing HR contact map 3731
# Computing HR contact map 3732
# Computing HR contact map 3733
# Computing HR contact map 3734
# Computing HR contact map 3735
# Computing HR contact map 3736
# Computing HR contact map 3737
# Computing HR contact map 3738
# Computing HR contact map 3739
# Computing HR contact map 3740
# Computing HR contact map 3741
# Computing HR contact map 3742
# Computing HR contact map 3743
# Computing HR contact map 3744
# Computing HR contact map 3745
# Computing HR contact map 3746
# Computing HR contact map 3747
# Computing HR contact map 3748
# Computing HR contact map 3749
# Computing HR contact map 3750
# All distance maps retrieved
# Computing global LR contact map
# 50 1225 200
# Generating 3D ensambles with downsampled chains: 3750
# Submitted batch job 41592279

# %%
importlib.reload(synth_utils)
chains_downsample_factors = [100,250,1000,2500,3750,5000]
for ds in chains_downsample_factors:
    synth_utils.read_pcSAC_reconstruction(downsampled_chains=int(ds),distance=1500)
# Out:
# Submitted batch job 41645486
# Submitted batch job 41645487
# Submitted batch job 41645488
# Submitted batch job 41645489
# Submitted batch job 41645490
# Submitted batch job 41645491

# %% [markdown]
# ### Detailed regions

# %% [markdown]
# ### chr16: 57000000 - 59500000

# %%
dSample = [16,25,50,100]
lr = 20
resolution= 10000
start=57000000
end=59500000
for ds in dSample:
    utils.run_genData(
        chr=16,
        start=start,
        end=end,
        downsample_factor=ds,
        hic_res=resolution, 
        lrbin=2,
        split_chains=False
    )
# Out:
# Submitted batch job 40632397
# Submitted batch job 40632398
# Submitted batch job 40632399
# Submitted batch job 40632400

# %%
#for 10K only 16
n_chains = [10000]
#dSample = [16,25,50,100]
dSample = [16]
lr = 20
resolution=10000
start=57000000
end=59500000
for n_c in n_chains:
    for ds in dSample:
        utils.run_pcSAC(downsampling_factor=ds,
                                lrf=lr,
                                run_option="whole",
                                number_chains=n_c,
                                split_chains=False,
                                region_size=int(end - start),
                                hic_res=resolution)
# Out:
# Submitted batch job 40636917

# %%
dSample = [16,25,50,100]
lr = 20
resolution= 10000
start=57000000
end=59500000

for i in dSample:
    reconstruct.run_reconstruction(downsampling_factor=int(i),
                                    lrf=20,
                                    run_option="whole",
                                    number_chains=10000,
                                    region_size = int(end - start),
                                    hic_res=10000,
                                    chromosome = 16,
                                    start=start)
# Out:
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '2500000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '16', '-s', '57000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41316887
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '25', '-z', '2500000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '16', '-s', '57000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41316888
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '50', '-z', '2500000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '16', '-s', '57000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41316889
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '100', '-z', '2500000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '16', '-s', '57000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41316890

# %% [markdown]
# ### chr17:73500000-75800000

# %%
dSample = [16,25,50,100]
lr = 20
resolution= 10000
start=73500000
end=75800000
chrn=17
for ds in dSample:
    utils.run_genData(
        chr=chrn,
        start=start,
        end=end,
        downsample_factor=ds,
        hic_res=resolution, 
        lrbin=2,
        split_chains=False
    )
# Out:
# Submitted batch job 40632483
# Submitted batch job 40632484
# Submitted batch job 40632485
# Submitted batch job 40632486

# %%
n_chains = [10000]
dSample = [16]
lr = 20
resolution= 10000
start=73500000
end=75800000
chrn=17
for n_c in n_chains:
    for ds in dSample:
        utils.run_pcSAC(downsampling_factor=ds,
                                lrf=lr,
                                run_option="whole",
                                number_chains=n_c,
                                split_chains=False,
                                region_size=int(end - start),
                                hic_res=resolution)
# Out:
# Submitted batch job 40636921

# %%
dSample = [16,25,50,100]
lr = 20
resolution= 10000
start=73500000
end=75800000
chrn=17

for i in dSample:
    reconstruct.run_reconstruction(downsampling_factor=int(i),
                                    lrf=20,
                                    run_option="whole",
                                    number_chains=1000,
                                    region_size = int(end - start),
                                    hic_res=10000,
                                    chromosome = chrn,
                                    start=start)
# Out:
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '2300000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '1000', '-c', '17', '-s', '73500000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41316893
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '25', '-z', '2300000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '1000', '-c', '17', '-s', '73500000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41316894
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '50', '-z', '2300000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '1000', '-c', '17', '-s', '73500000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41316895
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '100', '-z', '2300000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '1000', '-c', '17', '-s', '73500000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41316896

# %% [markdown]
# ### chr22:23000000-24900000

# %%
dSample = [16,25,50,100]
lr = 20
resolution= 10000
start=23000000
end=24900000
chrn=22
for ds in dSample:
    utils.run_genData(
        chr=chrn,
        start=start,
        end=end,
        downsample_factor=ds,
        hic_res=resolution, 
        lrbin=2,
        split_chains=False
    )
# Out:
# Submitted batch job 40632505
# Submitted batch job 40632506
# Submitted batch job 40632507
# Submitted batch job 40632508

# %%
n_chains = [10000]
dSample = [16]
lr = 20
resolution= 10000
start=23000000
end=24900000
chrn=22
for n_c in n_chains:
    for ds in dSample:
        utils.run_pcSAC(downsampling_factor=ds,
                                lrf=lr,
                                run_option="whole",
                                number_chains=n_c,
                                split_chains=False,
                                region_size=int(end - start),
                                hic_res=resolution)
# Out:
# Submitted batch job 40636925

# %%
dSample = [16,25,50,100]
lr = 20
resolution= 10000
start=23000000
end=24900000
chrn=22

for i in dSample:
    reconstruct.run_reconstruction(downsampling_factor=int(i),
                                    lrf=20,
                                    run_option="whole",
                                    number_chains=1000,
                                    region_size = int(end - start),
                                    hic_res=resolution,
                                    chromosome = chrn,
                                    start=start)
# Out:
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '1900000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '1000', '-c', '22', '-s', '23000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41316902
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '25', '-z', '1900000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '1000', '-c', '22', '-s', '23000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41316903
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '50', '-z', '1900000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '1000', '-c', '22', '-s', '23000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41316904
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '100', '-z', '1900000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '1000', '-c', '22', '-s', '23000000', '-i', '160', '-t', 'GM12878']
# Submitted batch job 41316905

# %% [markdown]
# ## Different cell lines

# %% [markdown]
# 11/10/23
#
# v2.0 added cell_type in ensambles_3D and modified part 2 of the general pipeline to identify cell type

# %%
import utils

# %%
dSample = [3,5,10,20] # proportional to original ones
for ds in dSample:
    utils.run_genData(
        file=globals.hic_K562,
        chr=globals.chromosome,
        start=globals.start,
        end=globals.end,
        downsample_factor=ds,
        hic_res=10000, 
        lrbin=2,
        split_chains=False
    )
# Out:
# Submitted batch job 40856708
# Submitted batch job 40856709
# Submitted batch job 40856710
# Submitted batch job 40856711

# %%
for ds in dSample:    
    utils.run_genData(
        file=globals.hic_IMR90,
        chr=globals.chromosome,
        start=globals.start,
        end=globals.end,
        downsample_factor=ds,
        hic_res=10000, 
        lrbin=2,
        split_chains=False
    )
# Out:
# Submitted batch job 40856718
# Submitted batch job 40856719
# Submitted batch job 40856720
# Submitted batch job 40856721

# %%
for ds in dSample:    
    utils.run_pcSAC(downsampling_factor=ds,
                            lrf=20,
                            run_option="whole",
                            number_chains=10000,
                            split_chains=False,
                            region_size=globals.size,
                            hic_res=10000,
                            cell="K562")
# Out:
# Submitted batch job 40857017
# Submitted batch job 40857018
# Submitted batch job 40857019
# Submitted batch job 40857020

# %%
for ds in dSample:    
    utils.run_pcSAC(downsampling_factor=ds,
                            lrf=20,
                            run_option="whole",
                            number_chains=10000,
                            split_chains=False,
                            region_size=globals.size,
                            hic_res=10000,
                            cell="IMR90")
# Out:
# Submitted batch job 40857024
# Submitted batch job 40857025
# Submitted batch job 40857026
# Submitted batch job 40857027

# %%
dSample = [3,5,10,20] 
for i in dSample:
    reconstruct.run_reconstruction(downsampling_factor=int(i),
                                    lrf=20,
                                    run_option="whole",
                                    number_chains=10000,
                                    region_size = globals.size,
                                    hic_res=10000,
                                    chromosome = globals.chromosome,
                                    start=globals.start,
                                    cell_t="K562")
# Out:
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '3', '-z', '2000000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '100000', '-i', '170', '-t', 'K562']
# Submitted batch job 40883178
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '5', '-z', '2000000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '100000', '-i', '170', '-t', 'K562']
# Submitted batch job 40883179
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '10', '-z', '2000000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '100000', '-i', '170', '-t', 'K562']
# Submitted batch job 40883180
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '20', '-z', '2000000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '100000', '-i', '170', '-t', 'K562']
# Submitted batch job 40883181

# %%
dSample = [3,5,10,20] 
for i in dSample:
    reconstruct.run_reconstruction(downsampling_factor=int(i),
                                    lrf=20,
                                    run_option="whole",
                                    number_chains=10000,
                                    region_size = globals.size,
                                    hic_res=10000,
                                    chromosome = globals.chromosome,
                                    start=globals.start,
                                    cell_t="IMR90")
# Out:
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '3', '-z', '2000000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '100000', '-i', '170', '-t', 'IMR90']
# Submitted batch job 40883188
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '5', '-z', '2000000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '100000', '-i', '170', '-t', 'IMR90']
# Submitted batch job 40883189
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '10', '-z', '2000000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '100000', '-i', '170', '-t', 'IMR90']
# Submitted batch job 40883190
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '20', '-z', '2000000', '-h', '10000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '100000', '-i', '170', '-t', 'IMR90']
# Submitted batch job 40883191

# %% [markdown]
# 5kb

# %%
# Source utils not general utils 
utils.run_genData(
    chr=globals.chromosome,
    start=globals.start,
    end=globals.end,
    downsample_factor=16,
    hic_res=5000, 
    lrbin=4,
    split_chains=False,
    file=globals.hic_file
)
# Out:
# Submitted batch job 43693214

# %%
for ds in [25,50,100]:
    utils.run_genData(
        chr=globals.chromosome,
        start=globals.start,
        end=globals.end,
        downsample_factor=ds,
        hic_res=5000, 
        lrbin=4,
        split_chains=False,
        file=globals.hic_file
    )
# Out:
# Submitted batch job 43693233
# Submitted batch job 43693234
# Submitted batch job 43693235

# %%
for ds in [25,50,100]:
    utils.run_pcSAC(
                    chromosome=str("chr")+"20",
                    downsampling_factor=ds,
                    lrf=20,
                    run_option="whole",
                    number_chains=10000,
                    split_chains=False,
                    region_size=int(globals.end-globals.start),
                    hic_res=5000,
                    cell="GM12878")
# Out:
# Submitted batch job 43693239
# Submitted batch job 43693240
# Submitted batch job 43693241

# %%
for ds in [16,25,50,100]:
    reconstruct.run_reconstruction(downsampling_factor=int(ds),
                                    lrf=20,
                                    run_option="whole",
                                    number_chains=10000,
                                    region_size = globals.size,
                                    hic_res=5000,
                                    chromosome = globals.chromosome,
                                    start=globals.start,
                                    cell_t="GM12878")
# Out:
# ['sbatch', '/gpfs/commons/home/cangel/g2lab/projects/01_12_23_highResolutionHiC/scripts/ParameterTuning/03.compare_matrices.sh', '-d', '16', '-z', '2000000', '-h', '5000', '-l', '20', '-o', 'whole', '-n', '10000', '-c', '20', '-s', '100000', '-i', '99', '-t', 'GM12878']
# Submitted batch job 45595831
